# %% [markdown]
# ### s1_cookies_vs_profile

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import itertools
from scipy.stats import permutation_test
import os

def bootstrap_ci(data, statistic, alpha):
    """Compute bootstrap confidence interval for given data and statistic."""
    bs_replicates = np.empty(10000)
    
    for i in range(10000):
        bs_sample = np.random.choice(data, len(data))
        bs_replicates[i] = statistic(bs_sample)
        
    return np.percentile(bs_replicates, [100 * alpha / 2., 100 * (1 - alpha / 2.)])

# Define the function for test statistic (difference of means)
def test_statistic(a, b):
    return np.mean(a) - np.mean(b)

# Load the data into a DataFrame
path = os.getcwd() + "/datasets-stats/s1_cookies_vs_profile.csv"
df = pd.read_csv(path)

# Get unique alias
aliases = df['alias'].unique()

# Generate all pairs of aliases
pairs = list(itertools.combinations(aliases, 2))

# Perform permutation test for each pair
for pair in pairs:
    group1 = df[df['alias'] == pair[0]]['ct'].to_numpy()
    group2 = df[df['alias'] == pair[1]]['ct'].to_numpy()
    
    result = stats.permutation_test((group1, group2), 
                                    test_statistic,
                                    vectorized=False,
                                    alternative='two-sided',
                                    permutation_type='independent')
    
    # Calculate bootstrap confidence intervals for the mean
    ci_group1 = bootstrap_ci(group1, np.mean, 0.05)
    ci_group2 = bootstrap_ci(group2, np.mean, 0.05)
    
    print(f'Pair: {pair}, P-value: {result.pvalue}, CI Group1: {ci_group1}, CI Group2: {ci_group2}')
# Out:
# Pair: ('#1', '#2'), P-value: 0.0004, CI Group1: [31.88521183 33.05816523], CI Group2: [30.14130065 31.25527888]
# Pair: ('#1', '#3'), P-value: 0.0002, CI Group1: [31.88543871 33.07015799], CI Group2: [35.25710117 36.54462627]
# Pair: ('#1', '#4'), P-value: 0.0002, CI Group1: [31.88088941 33.06460949], CI Group2: [29.95791511 31.05916741]
# Pair: ('#1', '#5'), P-value: 0.0002, CI Group1: [31.88898176 33.06381718], CI Group2: [15.15284171 15.74863438]
# Pair: ('#1', '#6'), P-value: 0.0002, CI Group1: [31.8750482  33.05991442], CI Group2: [35.21164357 36.57936763]
# Pair: ('#1', '#7'), P-value: 0.0002, CI Group1: [31.87170969 33.06886843], CI Group2: [37.92008085 39.44775138]
# Pair: ('#1', '#8'), P-value: 0.0002, CI Group1: [31.87322848 33.06687826], CI Group2: [30.16748295 31.26853093]
# Pair: ('#1', '#9'), P-value: 0.0002, CI Group1: [31.86443669 33.07373748], CI Group2: [64.37913237 67.21028414]
# Pair: ('#2', '#3'), P-value: 0.0002, CI Group1: [30.13666407 31.25408756], CI Group2: [35.25841426 36.57618353]
# Pair: ('#2', '#4'), P-value: 0.628, CI Group1: [30.14326414 31.26216232], CI Group2: [29.95146594 31.05379704]
# Pair: ('#2', '#5'), P-value: 0.0002, CI Group1: [30.15102484 31.25311585], CI Group2: [15.15828478 15.74532896]
# Pair: ('#2', '#6'), P-value: 0.0002, CI Group1: [30.15580429 31.26731723], CI Group2: [35.21290785 36.57872975]
# Pair: ('#2', '#7'), P-value: 0.0002, CI Group1: [30.13747402 31.25876193], CI Group2: [37.90872225 39.44012869]
# Pair: ('#2', '#8'), P-value: 0.9792, CI Group1: [30.13663691 31.24993742], CI Group2: [30.15936197 31.26431769]
# Pair: ('#2', '#9'), P-value: 0.0002, CI Group1: [30.14309767 31.26024488], CI Group2: [64.34755028 67.2554724 ]
# Pair: ('#3', '#4'), P-value: 0.0002, CI Group1: [35.25738597 36.56263481], CI Group2: [29.94877248 31.0574725 ]
# Pair: ('#3', '#5'), P-value: 0.0002, CI Group1: [35.24986227 36.5707456 ], CI Group2: [15.15969653 15.75296917]
# Pair: ('#3', '#6'), P-value: 0.9882, CI Group1: [35.24827723 36.57019819], CI Group2: [35.19815405 36.58967234]
# Pair: ('#3', '#7'), P-value: 0.0002, CI Group1: [35.27073626 36.57842103], CI Group2: [37.91715811 39.44770895]
# Pair: ('#3', '#8'), P-value: 0.0002, CI Group1: [35.2567265  36.57130235], CI Group2: [30.1673148  31.25829505]
# Pair: ('#3', '#9'), P-value: 0.0002, CI Group1: [35.23465148 36.54728862], CI Group2: [64.38006548 67.25983396]
# Pair: ('#4', '#5'), P-value: 0.0002, CI Group1: [29.94058944 31.06701171], CI Group2: [15.15950473 15.75834183]
# Pair: ('#4', '#6'), P-value: 0.0002, CI Group1: [29.95646924 31.05486639], CI Group2: [35.21930958 36.58376623]
# Pair: ('#4', '#7'), P-value: 0.0002, CI Group1: [29.95876729 31.04801945], CI Group2: [37.91678216 39.45373238]
# Pair: ('#4', '#8'), P-value: 0.6146, CI Group1: [29.95410037 31.05029153], CI Group2: [30.1554874  31.25402615]
# Pair: ('#4', '#9'), P-value: 0.0002, CI Group1: [29.95414759 31.05779472], CI Group2: [64.36309401 67.25193756]
# Pair: ('#5', '#6'), P-value: 0.0002, CI Group1: [15.15940762 15.75115319], CI Group2: [35.2178342  36.57043963]
# Pair: ('#5', '#7'), P-value: 0.0002, CI Group1: [15.16658534 15.74596504], CI Group2: [37.91362254 39.43530382]
# Pair: ('#5', '#8'), P-value: 0.0002, CI Group1: [15.1609007  15.74892207], CI Group2: [30.16061718 31.26858185]
# Pair: ('#5', '#9'), P-value: 0.0002, CI Group1: [15.15876548 15.75181112], CI Group2: [64.40203812 67.25090037]
# Pair: ('#6', '#7'), P-value: 0.0002, CI Group1: [35.20351407 36.59056606], CI Group2: [37.90557088 39.41820346]
# Pair: ('#6', '#8'), P-value: 0.0002, CI Group1: [35.20118283 36.57875384], CI Group2: [30.16059232 31.26319037]
# Pair: ('#6', '#9'), P-value: 0.0002, CI Group1: [35.2238883  36.56545248], CI Group2: [64.36937675 67.24903181]
# Pair: ('#7', '#8'), P-value: 0.0002, CI Group1: [37.91310046 39.44657521], CI Group2: [30.15724943 31.25957039]
# Pair: ('#7', '#9'), P-value: 0.0002, CI Group1: [37.9233371  39.44713973], CI Group2: [64.39685337 67.22138915]
# Pair: ('#8', '#9'), P-value: 0.0002, CI Group1: [30.16128268 31.26108611], CI Group2: [64.4027362 67.2271457]

# %% [markdown]
# ### s2_1s-3rd_vs_profile

# %% [markdown]
# ##### 1st-party

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import itertools
from scipy.stats import permutation_test
import os

path = os.getcwd() + "/datasets-stats/s2_1s-3rd_vs_profile.csv"

df = pd.read_csv(path)

df = df.dropna(subset=['is_third_party'])

# Create a new column combining 'alias' and 'is_third_party'
df['alias_third_party'] = df['alias'].astype(str) + '_' + df['is_third_party'].astype(str)

# Get unique alias_third_party
aliases_third_party = df['alias_third_party'].unique()

# Generate all pairs of alias_third_party
pairs = list(itertools.combinations(aliases_third_party, 2))


def bootstrap_ci(data, statistic, alpha):
    """Compute bootstrap confidence interval for given data and statistic."""
    bs_replicates = np.empty(10000)
    
    for i in range(10000):
        bs_sample = np.random.choice(data, len(data))
        bs_replicates[i] = statistic(bs_sample)
        
    return np.percentile(bs_replicates, [100 * alpha / 2., 100 * (1 - alpha / 2.)])

# Perform permutation test for each pair
for pair in pairs:
    group1 = df[df['alias_third_party'] == pair[0]]['ct'].to_numpy()
    group2 = df[df['alias_third_party'] == pair[1]]['ct'].to_numpy()
    
    result = stats.permutation_test((group1, group2), 
                                    #func=test_statistic, 
                                    #method='exact',
                                    test_statistic,
                                    vectorized=False,
                                    alternative='two-sided',
                                    permutation_type='independent')
    
    # Calculate bootstrap confidence intervals for the mean
    ci_group1 = bootstrap_ci(group1, np.mean, 0.05)
    ci_group2 = bootstrap_ci(group2, np.mean, 0.05)
    
    
    print(f'Pair: {pair}, P-value: {result.pvalue}, CI Group1: {ci_group1}, CI Group2: {ci_group2}')
# Out:
# Pair: ('1_1.0', '1_0.0'), P-value: 0.0002, CI Group1: [22.93514277 24.07044874], CI Group2: [14.14035375 14.57784401]
# Pair: ('1_1.0', '2_1.0'), P-value: 0.0002, CI Group1: [22.92738136 24.08533719], CI Group2: [21.09909374 22.18805303]
# Pair: ('1_1.0', '2_0.0'), P-value: 0.0002, CI Group1: [22.93190849 24.08486745], CI Group2: [13.92219456 14.34218595]
# Pair: ('1_1.0', '3_1.0'), P-value: 0.0002, CI Group1: [22.92012943 24.08102293], CI Group2: [25.9213198  27.20516679]
# Pair: ('1_1.0', '3_0.0'), P-value: 0.0002, CI Group1: [22.93323967 24.07610837], CI Group2: [14.86319917 15.31242532]
# Pair: ('1_1.0', '4_0.0'), P-value: 0.0002, CI Group1: [22.92564146 24.06261779], CI Group2: [13.80192118 14.22799428]
# Pair: ('1_1.0', '4_1.0'), P-value: 0.0002, CI Group1: [22.92747502 24.09520606], CI Group2: [21.06423333 22.11794637]
# Pair: ('1_1.0', '5_1.0'), P-value: 0.0002, CI Group1: [22.93135502 24.0715273 ], CI Group2: [ 9.57231003 10.08839415]
# Pair: ('1_1.0', '5_0.0'), P-value: 0.0002, CI Group1: [22.94101385 24.05571923], CI Group2: [8.63620885 8.96356839]
# Pair: ('1_1.0', '6_1.0'), P-value: 0.0002, CI Group1: [22.93491996 24.07300182], CI Group2: [25.83810884 27.22186179]
# Pair: ('1_1.0', '6_0.0'), P-value: 0.0002, CI Group1: [22.94688351 24.09043341], CI Group2: [14.88233386 15.32340294]
# Pair: ('1_1.0', '7_1.0'), P-value: 0.0002, CI Group1: [22.93042972 24.0773842 ], CI Group2: [28.6372174  30.18017985]
# Pair: ('1_1.0', '7_0.0'), P-value: 0.0002, CI Group1: [22.92085746 24.08549614], CI Group2: [15.34716033 15.80318194]
# Pair: ('1_1.0', '8_1.0'), P-value: 0.0008, CI Group1: [22.94078253 24.08072349], CI Group2: [21.70267837 22.78138234]
# Pair: ('1_1.0', '8_0.0'), P-value: 0.0002, CI Group1: [22.9367592  24.08651368], CI Group2: [13.482025   13.89692485]
# Pair: ('1_1.0', '9_1.0'), P-value: 0.0002, CI Group1: [22.93393648 24.08322264], CI Group2: [58.67379402 61.67040788]
# Pair: ('1_1.0', '9_0.0'), P-value: 0.0002, CI Group1: [22.93087676 24.08924557], CI Group2: [16.03754559 16.52078047]
# Pair: ('1_0.0', '2_1.0'), P-value: 0.0002, CI Group1: [14.14439899 14.58080749], CI Group2: [21.10560313 22.17959839]
# Pair: ('1_0.0', '2_0.0'), P-value: 0.1416, CI Group1: [14.14482235 14.57864267], CI Group2: [13.91792251 14.34265135]
# Pair: ('1_0.0', '3_1.0'), P-value: 0.0002, CI Group1: [14.13370215 14.58137369], CI Group2: [25.90907012 27.20846489]
# Pair: ('1_0.0', '3_0.0'), P-value: 0.0002, CI Group1: [14.14450808 14.58236325], CI Group2: [14.86206865 15.30948702]
# Pair: ('1_0.0', '4_0.0'), P-value: 0.0222, CI Group1: [14.14046024 14.58012701], CI Group2: [13.79947841 14.22299818]
# Pair: ('1_0.0', '4_1.0'), P-value: 0.0002, CI Group1: [14.14575736 14.58689419], CI Group2: [21.06022089 22.11215047]
# Pair: ('1_0.0', '5_1.0'), P-value: 0.0002, CI Group1: [14.14299387 14.58106332], CI Group2: [ 9.57568642 10.08713271]
# Pair: ('1_0.0', '5_0.0'), P-value: 0.0002, CI Group1: [14.15017402 14.57893616], CI Group2: [8.63518729 8.95834279]
# Pair: ('1_0.0', '6_1.0'), P-value: 0.0002, CI Group1: [14.15032726 14.5858397 ], CI Group2: [25.86438828 27.21311295]
# Pair: ('1_0.0', '6_0.0'), P-value: 0.0002, CI Group1: [14.14658329 14.58138279], CI Group2: [14.88450157 15.3236567 ]
# Pair: ('1_0.0', '7_1.0'), P-value: 0.0002, CI Group1: [14.1460093  14.58090619], CI Group2: [28.62061087 30.14019282]
# Pair: ('1_0.0', '7_0.0'), P-value: 0.0002, CI Group1: [14.14554958 14.58428134], CI Group2: [15.34482041 15.80276809]
# Pair: ('1_0.0', '8_1.0'), P-value: 0.0002, CI Group1: [14.14284842 14.58153213], CI Group2: [21.71552071 22.77906502]
# Pair: ('1_0.0', '8_0.0'), P-value: 0.0002, CI Group1: [14.14231598 14.58409044], CI Group2: [13.47962319 13.89869777]
# Pair: ('1_0.0', '9_1.0'), P-value: 0.0002, CI Group1: [14.14320295 14.58496961], CI Group2: [58.69302075 61.69495805]
# Pair: ('1_0.0', '9_0.0'), P-value: 0.0002, CI Group1: [14.1403992  14.58410862], CI Group2: [16.03985824 16.51841517]
# Pair: ('2_1.0', '2_0.0'), P-value: 0.0002, CI Group1: [21.08790889 22.17977108], CI Group2: [13.91796553 14.34298378]
# Pair: ('2_1.0', '3_1.0'), P-value: 0.0002, CI Group1: [21.1062211  22.16187418], CI Group2: [25.92440592 27.20366486]
# Pair: ('2_1.0', '3_0.0'), P-value: 0.0002, CI Group1: [21.10735857 22.18086288], CI Group2: [14.85748352 15.30716934]
# Pair: ('2_1.0', '4_0.0'), P-value: 0.0002, CI Group1: [21.10433722 22.17491865], CI Group2: [13.80853278 14.22201223]
# Pair: ('2_1.0', '4_1.0'), P-value: 0.8992, CI Group1: [21.10303848 22.18713678], CI Group2: [21.07526931 22.12451581]
# Pair: ('2_1.0', '5_1.0'), P-value: 0.0002, CI Group1: [21.0927028  22.19357339], CI Group2: [ 9.57188855 10.09224621]
# Pair: ('2_1.0', '5_0.0'), P-value: 0.0002, CI Group1: [21.10422732 22.17257521], CI Group2: [8.63631243 8.95817395]
# Pair: ('2_1.0', '6_1.0'), P-value: 0.0002, CI Group1: [21.09564851 22.19073757], CI Group2: [25.84590495 27.2138927 ]
# Pair: ('2_1.0', '6_0.0'), P-value: 0.0002, CI Group1: [21.112348   22.18696124], CI Group2: [14.88268357 15.32173644]
# Pair: ('2_1.0', '7_1.0'), P-value: 0.0002, CI Group1: [21.11365531 22.17642005], CI Group2: [28.63971218 30.15742798]
# Pair: ('2_1.0', '7_0.0'), P-value: 0.0002, CI Group1: [21.0836887  22.17743335], CI Group2: [15.34302837 15.80536179]
# Pair: ('2_1.0', '8_1.0'), P-value: 0.1182, CI Group1: [21.09756094 22.16494691], CI Group2: [21.70895713 22.78032509]
# Pair: ('2_1.0', '8_0.0'), P-value: 0.0002, CI Group1: [21.10468545 22.16562339], CI Group2: [13.4831285  13.89321296]
# Pair: ('2_1.0', '9_1.0'), P-value: 0.0002, CI Group1: [21.09218616 22.16881886], CI Group2: [58.67044652 61.67428248]
# Pair: ('2_1.0', '9_0.0'), P-value: 0.0002, CI Group1: [21.10165982 22.18359736], CI Group2: [16.0337421  16.51066182]
# Pair: ('2_0.0', '3_1.0'), P-value: 0.0002, CI Group1: [13.91880769 14.34536424], CI Group2: [25.91573325 27.21108663]
# Pair: ('2_0.0', '3_0.0'), P-value: 0.0002, CI Group1: [13.91875424 14.3457801 ], CI Group2: [14.85944582 15.30981793]
# Pair: ('2_0.0', '4_0.0'), P-value: 0.4438, CI Group1: [13.91854696 14.3420256 ], CI Group2: [13.7987435  14.23216051]
# Pair: ('2_0.0', '4_1.0'), P-value: 0.0002, CI Group1: [13.91619257 14.34333316], CI Group2: [21.07120387 22.11981721]
# Pair: ('2_0.0', '5_1.0'), P-value: 0.0002, CI Group1: [13.91864995 14.34265526], CI Group2: [ 9.56736814 10.08580804]
# Pair: ('2_0.0', '5_0.0'), P-value: 0.0002, CI Group1: [13.91535563 14.34327971], CI Group2: [8.63870034 8.95959279]
# Pair: ('2_0.0', '6_1.0'), P-value: 0.0002, CI Group1: [13.91202221 14.34390285], CI Group2: [25.84915024 27.23745264]
# Pair: ('2_0.0', '6_0.0'), P-value: 0.0002, CI Group1: [13.91484461 14.34353914], CI Group2: [14.88152586 15.32426144]
# Pair: ('2_0.0', '7_1.0'), P-value: 0.0002, CI Group1: [13.9191701  14.34218856], CI Group2: [28.63132999 30.12958646]
# Pair: ('2_0.0', '7_0.0'), P-value: 0.0002, CI Group1: [13.91828623 14.34656359], CI Group2: [15.34512884 15.80989198]
# Pair: ('2_0.0', '8_1.0'), P-value: 0.0002, CI Group1: [13.91870339 14.34083929], CI Group2: [21.71892405 22.787979  ]
# Pair: ('2_0.0', '8_0.0'), P-value: 0.0034, CI Group1: [13.92047374 14.34072065], CI Group2: [13.48035014 13.89498719]
# Pair: ('2_0.0', '9_1.0'), P-value: 0.0002, CI Group1: [13.91739714 14.34192131], CI Group2: [58.68125621 61.70750221]
# Pair: ('2_0.0', '9_0.0'), P-value: 0.0002, CI Group1: [13.92088439 14.3482831 ], CI Group2: [16.03076429 16.51708357]
# Pair: ('3_1.0', '3_0.0'), P-value: 0.0002, CI Group1: [25.93606571 27.20913287], CI Group2: [14.86160641 15.30974454]
# Pair: ('3_1.0', '4_0.0'), P-value: 0.0002, CI Group1: [25.91452279 27.20918726], CI Group2: [13.8037461 14.2260757]
# Pair: ('3_1.0', '4_1.0'), P-value: 0.0002, CI Group1: [25.92445473 27.20044347], CI Group2: [21.07666457 22.12485818]
# Pair: ('3_1.0', '5_1.0'), P-value: 0.0002, CI Group1: [25.92526357 27.20835332], CI Group2: [ 9.56472032 10.09634363]
# Pair: ('3_1.0', '5_0.0'), P-value: 0.0002, CI Group1: [25.92976516 27.20650834], CI Group2: [8.63840948 8.95414444]
# Pair: ('3_1.0', '6_1.0'), P-value: 0.9472, CI Group1: [25.91303062 27.19920232], CI Group2: [25.8649072 27.2083164]
# Pair: ('3_1.0', '6_0.0'), P-value: 0.0002, CI Group1: [25.92475038 27.20818179], CI Group2: [14.88612009 15.32709322]
# Pair: ('3_1.0', '7_1.0'), P-value: 0.0002, CI Group1: [25.90062197 27.1870405 ], CI Group2: [28.61981733 30.16113633]
# Pair: ('3_1.0', '7_0.0'), P-value: 0.0002, CI Group1: [25.9159243  27.20611647], CI Group2: [15.34742322 15.80178293]
# Pair: ('3_1.0', '8_1.0'), P-value: 0.0002, CI Group1: [25.92190411 27.19741312], CI Group2: [21.71852417 22.77866513]
# Pair: ('3_1.0', '8_0.0'), P-value: 0.0002, CI Group1: [25.9292687  27.19759859], CI Group2: [13.48297029 13.89697715]
# Pair: ('3_1.0', '9_1.0'), P-value: 0.0002, CI Group1: [25.91006164 27.20170832], CI Group2: [58.64940943 61.67612733]
# Pair: ('3_1.0', '9_0.0'), P-value: 0.0002, CI Group1: [25.91889189 27.19146678], CI Group2: [16.03291772 16.51605244]
# Pair: ('3_0.0', '4_0.0'), P-value: 0.0002, CI Group1: [14.86505588 15.3104656 ], CI Group2: [13.79858611 14.2298166 ]
# Pair: ('3_0.0', '4_1.0'), P-value: 0.0002, CI Group1: [14.86299701 15.3097587 ], CI Group2: [21.05878266 22.11207884]
# Pair: ('3_0.0', '5_1.0'), P-value: 0.0002, CI Group1: [14.86073213 15.31319788], CI Group2: [ 9.57531611 10.09062048]
# Pair: ('3_0.0', '5_0.0'), P-value: 0.0002, CI Group1: [14.86500309 15.30815693], CI Group2: [8.63552355 8.95738224]
# Pair: ('3_0.0', '6_1.0'), P-value: 0.0002, CI Group1: [14.85882777 15.3105171 ], CI Group2: [25.85390972 27.22503707]
# Pair: ('3_0.0', '6_0.0'), P-value: 0.9104, CI Group1: [14.85882133 15.31391636], CI Group2: [14.88319109 15.32063175]
# Pair: ('3_0.0', '7_1.0'), P-value: 0.0002, CI Group1: [14.86021194 15.31269443], CI Group2: [28.6192028  30.15945481]
# Pair: ('3_0.0', '7_0.0'), P-value: 0.0028, CI Group1: [14.85526885 15.31062139], CI Group2: [15.34892634 15.80650963]
# Pair: ('3_0.0', '8_1.0'), P-value: 0.0002, CI Group1: [14.85589076 15.31206865], CI Group2: [21.70989356 22.777792  ]
# Pair: ('3_0.0', '8_0.0'), P-value: 0.0002, CI Group1: [14.86377086 15.3120635 ], CI Group2: [13.48239893 13.89791329]
# Pair: ('3_0.0', '9_1.0'), P-value: 0.0002, CI Group1: [14.86304852 15.31542027], CI Group2: [58.69132907 61.71028259]
# Pair: ('3_0.0', '9_0.0'), P-value: 0.0002, CI Group1: [14.86361248 15.30835909], CI Group2: [16.0327174  16.51112153]
# Pair: ('4_0.0', '4_1.0'), P-value: 0.0002, CI Group1: [13.80171436 14.22364204], CI Group2: [21.04297072 22.11489801]
# Pair: ('4_0.0', '5_1.0'), P-value: 0.0002, CI Group1: [13.80030957 14.22887877], CI Group2: [ 9.57097333 10.09231244]
# Pair: ('4_0.0', '5_0.0'), P-value: 0.0002, CI Group1: [13.7937461  14.22617586], CI Group2: [8.63592083 8.96033343]
# Pair: ('4_0.0', '6_1.0'), P-value: 0.0002, CI Group1: [13.79672086 14.22341441], CI Group2: [25.87023914 27.2173494 ]
# Pair: ('4_0.0', '6_0.0'), P-value: 0.0002, CI Group1: [13.80389958 14.22705775], CI Group2: [14.88748359 15.32557444]
# Pair: ('4_0.0', '7_1.0'), P-value: 0.0002, CI Group1: [13.79889438 14.22711238], CI Group2: [28.63011642 30.15972402]
# Pair: ('4_0.0', '7_0.0'), P-value: 0.0002, CI Group1: [13.7966155  14.22866805], CI Group2: [15.34788652 15.80822749]
# Pair: ('4_0.0', '8_1.0'), P-value: 0.0002, CI Group1: [13.79879943 14.2248244 ], CI Group2: [21.70811133 22.78148878]
# Pair: ('4_0.0', '8_0.0'), P-value: 0.033, CI Group1: [13.80145291 14.2226847 ], CI Group2: [13.48255844 13.90434993]
# Pair: ('4_0.0', '9_1.0'), P-value: 0.0002, CI Group1: [13.80353668 14.22741935], CI Group2: [58.64819103 61.71047439]
# Pair: ('4_0.0', '9_0.0'), P-value: 0.0002, CI Group1: [13.80291103 14.22305021], CI Group2: [16.03244003 16.51564025]
# Pair: ('4_1.0', '5_1.0'), P-value: 0.0002, CI Group1: [21.06806956 22.11294837], CI Group2: [ 9.56953727 10.09135959]
# Pair: ('4_1.0', '5_0.0'), P-value: 0.0002, CI Group1: [21.05695049 22.13134025], CI Group2: [8.63359677 8.95703746]
# Pair: ('4_1.0', '6_1.0'), P-value: 0.0002, CI Group1: [21.05253839 22.13398321], CI Group2: [25.85535528 27.21774477]
# Pair: ('4_1.0', '6_0.0'), P-value: 0.0002, CI Group1: [21.05534609 22.10567986], CI Group2: [14.88150692 15.32426144]
# Pair: ('4_1.0', '7_1.0'), P-value: 0.0002, CI Group1: [21.06669436 22.12045324], CI Group2: [28.6222501 30.1701542]
# Pair: ('4_1.0', '7_0.0'), P-value: 0.0002, CI Group1: [21.05953329 22.12302888], CI Group2: [15.34812077 15.81041255]
# Pair: ('4_1.0', '8_1.0'), P-value: 0.0856, CI Group1: [21.06291113 22.12039308], CI Group2: [21.7039111  22.76754891]
# Pair: ('4_1.0', '8_0.0'), P-value: 0.0002, CI Group1: [21.0756919  22.13494442], CI Group2: [13.48050703 13.89519638]
# Pair: ('4_1.0', '9_1.0'), P-value: 0.0002, CI Group1: [21.05838443 22.1264411 ], CI Group2: [58.68794431 61.67901948]
# Pair: ('4_1.0', '9_0.0'), P-value: 0.0002, CI Group1: [21.05119041 22.13632105], CI Group2: [16.04411757 16.51682161]
# Pair: ('5_1.0', '5_0.0'), P-value: 0.0002, CI Group1: [ 9.56141317 10.09333303], CI Group2: [8.63876135 8.95569665]
# Pair: ('5_1.0', '6_1.0'), P-value: 0.0002, CI Group1: [ 9.56936266 10.09056178], CI Group2: [25.8540676  27.20921696]
# Pair: ('5_1.0', '6_0.0'), P-value: 0.0002, CI Group1: [ 9.57845014 10.08333785], CI Group2: [14.88454828 15.32396601]
# Pair: ('5_1.0', '7_1.0'), P-value: 0.0002, CI Group1: [ 9.56881172 10.09134453], CI Group2: [28.62280262 30.1628263 ]
# Pair: ('5_1.0', '7_0.0'), P-value: 0.0002, CI Group1: [ 9.57273151 10.09104197], CI Group2: [15.34460437 15.8008329 ]
# Pair: ('5_1.0', '8_1.0'), P-value: 0.0002, CI Group1: [ 9.5700852  10.09736723], CI Group2: [21.70865794 22.7943038 ]
# Pair: ('5_1.0', '8_0.0'), P-value: 0.0002, CI Group1: [ 9.56713481 10.09351367], CI Group2: [13.48072146 13.89592725]
# Pair: ('5_1.0', '9_1.0'), P-value: 0.0002, CI Group1: [ 9.57068882 10.08905949], CI Group2: [58.67284744 61.66611243]
# Pair: ('5_1.0', '9_0.0'), P-value: 0.0002, CI Group1: [ 9.57435724 10.09664469], CI Group2: [16.03723098 16.52098207]
# Pair: ('5_0.0', '6_1.0'), P-value: 0.0002, CI Group1: [8.63802497 8.95573212], CI Group2: [25.8534718  27.21773104]
# Pair: ('5_0.0', '6_0.0'), P-value: 0.0002, CI Group1: [8.63648978 8.95443104], CI Group2: [14.88510883 15.3214347 ]
# Pair: ('5_0.0', '7_1.0'), P-value: 0.0002, CI Group1: [8.63666146 8.95618899], CI Group2: [28.60890652 30.16149292]
# Pair: ('5_0.0', '7_0.0'), P-value: 0.0002, CI Group1: [8.63524262 8.96055902], CI Group2: [15.34737116 15.80073399]
# Pair: ('5_0.0', '8_1.0'), P-value: 0.0002, CI Group1: [8.63807605 8.95879824], CI Group2: [21.71177934 22.78297612]
# Pair: ('5_0.0', '8_0.0'), P-value: 0.0002, CI Group1: [8.63507236 8.95834705], CI Group2: [13.48318341 13.89190419]
# Pair: ('5_0.0', '9_1.0'), P-value: 0.0002, CI Group1: [8.63518729 8.96027951], CI Group2: [58.67659786 61.71488989]
# Pair: ('5_0.0', '9_0.0'), P-value: 0.0002, CI Group1: [8.63734251 8.96191827], CI Group2: [16.03656582 16.51046792]
# Pair: ('6_1.0', '6_0.0'), P-value: 0.0002, CI Group1: [25.85669238 27.21784087], CI Group2: [14.88515554 15.32502525]
# Pair: ('6_1.0', '7_1.0'), P-value: 0.0002, CI Group1: [25.86222201 27.20811735], CI Group2: [28.62292242 30.15816795]
# Pair: ('6_1.0', '7_0.0'), P-value: 0.0002, CI Group1: [25.85045851 27.20016062], CI Group2: [15.34570406 15.80640682]
# Pair: ('6_1.0', '8_1.0'), P-value: 0.0002, CI Group1: [25.85244495 27.22905936], CI Group2: [21.70440736 22.7733084 ]
# Pair: ('6_1.0', '8_0.0'), P-value: 0.0002, CI Group1: [25.84255532 27.22706057], CI Group2: [13.48255844 13.89367972]
# Pair: ('6_1.0', '9_1.0'), P-value: 0.0002, CI Group1: [25.86799187 27.20586871], CI Group2: [58.67838614 61.68049454]
# Pair: ('6_1.0', '9_0.0'), P-value: 0.0002, CI Group1: [25.84946186 27.20707677], CI Group2: [16.03285865 16.51353562]
# Pair: ('6_0.0', '7_1.0'), P-value: 0.0002, CI Group1: [14.88131754 15.32199399], CI Group2: [28.64596042 30.15891921]
# Pair: ('6_0.0', '7_0.0'), P-value: 0.0034, CI Group1: [14.88905035 15.32139304], CI Group2: [15.34820146 15.80364914]
# Pair: ('6_0.0', '8_1.0'), P-value: 0.0002, CI Group1: [14.88500909 15.32441673], CI Group2: [21.72593498 22.77748562]
# Pair: ('6_0.0', '8_0.0'), P-value: 0.0002, CI Group1: [14.88026462 15.32471594], CI Group2: [13.4802037 13.9014709]
# Pair: ('6_0.0', '9_1.0'), P-value: 0.0002, CI Group1: [14.87703136 15.32411751], CI Group2: [58.67515592 61.68806298]
# Pair: ('6_0.0', '9_0.0'), P-value: 0.0002, CI Group1: [14.88430462 15.33138193], CI Group2: [16.03527274 16.51985207]
# Pair: ('7_1.0', '7_0.0'), P-value: 0.0002, CI Group1: [28.61981733 30.1620102 ], CI Group2: [15.34528891 15.80458355]
# Pair: ('7_1.0', '8_1.0'), P-value: 0.0002, CI Group1: [28.63443508 30.13385578], CI Group2: [21.68612486 22.78659954]
# Pair: ('7_1.0', '8_0.0'), P-value: 0.0002, CI Group1: [28.62129306 30.14800417], CI Group2: [13.47999189 13.89750928]
# Pair: ('7_1.0', '9_1.0'), P-value: 0.0002, CI Group1: [28.61052461 30.14349524], CI Group2: [58.66839469 61.64273926]
# Pair: ('7_1.0', '9_0.0'), P-value: 0.0002, CI Group1: [28.6254609  30.15662457], CI Group2: [16.0351148  16.51250835]
# Pair: ('7_0.0', '8_1.0'), P-value: 0.0002, CI Group1: [15.34403826 15.80573529], CI Group2: [21.70137946 22.77689586]
# Pair: ('7_0.0', '8_0.0'), P-value: 0.0002, CI Group1: [15.3435177  15.80437793], CI Group2: [13.48275849 13.89755243]
# Pair: ('7_0.0', '9_1.0'), P-value: 0.0002, CI Group1: [15.34440396 15.81004685], CI Group2: [58.61875621 61.68854592]
# Pair: ('7_0.0', '9_0.0'), P-value: 0.0002, CI Group1: [15.34293597 15.80354503], CI Group2: [16.03564384 16.51374878]
# Pair: ('8_1.0', '8_0.0'), P-value: 0.0002, CI Group1: [21.69453107 22.77563579], CI Group2: [13.478942   13.89687124]
# Pair: ('8_1.0', '9_1.0'), P-value: 0.0002, CI Group1: [21.71812428 22.77912255], CI Group2: [58.64911966 61.68855696]
# Pair: ('8_1.0', '9_0.0'), P-value: 0.0002, CI Group1: [21.71080265 22.76951956], CI Group2: [16.03702424 16.51245955]
# Pair: ('8_0.0', '9_1.0'), P-value: 0.0002, CI Group1: [13.4794153  13.89911877], CI Group2: [58.65237057 61.66645049]
# Pair: ('8_0.0', '9_0.0'), P-value: 0.0002, CI Group1: [13.48134773 13.89676795], CI Group2: [16.03122528 16.51667266]
# Pair: ('9_1.0', '9_0.0'), P-value: 0.0002, CI Group1: [58.69389419 61.66812148], CI Group2: [16.03810802 16.51554651]

# %% [markdown]
# ### s3_cat_cookies_vs_profile

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import itertools
from scipy.stats import permutation_test

# Load the dataset
path = os.getcwd() + "/datasets-stats/s3_cat_cookies_vs_profile.csv"

df = pd.read_csv(path) 

# Get unique categories
categories = df['category'].unique()


def bootstrap_ci(data, statistic, alpha):
    """Compute bootstrap confidence interval for given data and statistic."""
    bs_replicates = np.empty(10000)
    
    for i in range(10000):
        bs_sample = np.random.choice(data, len(data))
        bs_replicates[i] = statistic(bs_sample)
        
    return np.percentile(bs_replicates, [100 * alpha / 2., 100 * (1 - alpha / 2.)])

# Prepare function for permutation test
def test_statistic(a, b):
    return np.mean(a) - np.mean(b)

# Iterate over each category
for category in categories:
    # Get unique aliases within this category
    aliases_in_category = df[df['category'] == category]['alias'].unique()

    # Generate all pairs of aliases
    pairs = list(itertools.combinations(aliases_in_category, 2))

    # Perform permutation test for each pair
    for pair in pairs:
        group1 = df[(df['alias'] == pair[0]) & (df['category'] == category)]['ct'].to_numpy()
        group2 = df[(df['alias'] == pair[1]) & (df['category'] == category)]['ct'].to_numpy()

        result = permutation_test((group1, group2), 
                                  test_statistic,
                                  vectorized=False,
                                  alternative='two-sided',
                                  permutation_type='independent')

        # Calculate bootstrap confidence intervals for the mean
        ci_group1 = bootstrap_ci(group1, np.mean, 0.05)
        ci_group2 = bootstrap_ci(group2, np.mean, 0.05)
        

        print(f'Category: {category}, Pair: {pair}, P-value: {result.pvalue}, CI Group1: {ci_group1}, CI Group2: {ci_group2}')
# Out:
# Category: Unknown, Pair: ('#1', '#2'), P-value: 0.0002, CI Group1: [4.89436715 5.011774  ], CI Group2: [4.69351749 4.8191838 ]
# Category: Unknown, Pair: ('#1', '#3'), P-value: 0.0002, CI Group1: [4.8927108  5.01152485], CI Group2: [5.13864221 5.26160795]
# Category: Unknown, Pair: ('#1', '#4'), P-value: 0.0002, CI Group1: [4.89352417 5.01180362], CI Group2: [4.60679215 4.72927428]
# Category: Unknown, Pair: ('#1', '#5'), P-value: 0.0002, CI Group1: [4.89214696 5.01121091], CI Group2: [3.06573669 3.14392195]
# Category: Unknown, Pair: ('#1', '#6'), P-value: 0.0002, CI Group1: [4.89592428 5.01251407], CI Group2: [5.14928389 5.27999473]
# Category: Unknown, Pair: ('#1', '#7'), P-value: 0.0002, CI Group1: [4.89426349 5.01098878], CI Group2: [5.61488346 5.75807269]
# Category: Unknown, Pair: ('#1', '#8'), P-value: 0.0002, CI Group1: [4.89371668 5.01253221], CI Group2: [4.54834263 4.66895414]
# Category: Unknown, Pair: ('#1', '#9'), P-value: 0.0002, CI Group1: [4.89398472 5.01110132], CI Group2: [8.90209002 9.13687765]
# Category: Unknown, Pair: ('#2', '#3'), P-value: 0.0002, CI Group1: [4.6923158  4.82121922], CI Group2: [5.13858963 5.25839129]
# Category: Unknown, Pair: ('#2', '#4'), P-value: 0.0438, CI Group1: [4.69302199 4.82192165], CI Group2: [4.60710769 4.72988885]
# Category: Unknown, Pair: ('#2', '#5'), P-value: 0.0002, CI Group1: [4.69299076 4.82151494], CI Group2: [3.06670549 3.14480701]
# Category: Unknown, Pair: ('#2', '#6'), P-value: 0.0002, CI Group1: [4.69524816 4.82032567], CI Group2: [5.15013654 5.28175678]
# Category: Unknown, Pair: ('#2', '#7'), P-value: 0.0002, CI Group1: [4.6937579  4.81948441], CI Group2: [5.61389992 5.75465555]
# Category: Unknown, Pair: ('#2', '#8'), P-value: 0.0012, CI Group1: [4.69258631 4.82004124], CI Group2: [4.54925705 4.67055741]
# Category: Unknown, Pair: ('#2', '#9'), P-value: 0.0002, CI Group1: [4.69374398 4.81937982], CI Group2: [8.90427091 9.13557714]
# Category: Unknown, Pair: ('#3', '#4'), P-value: 0.0002, CI Group1: [5.13822951 5.26006886], CI Group2: [4.60661265 4.72990422]
# Category: Unknown, Pair: ('#3', '#5'), P-value: 0.0002, CI Group1: [5.13838311 5.25932698], CI Group2: [3.06685895 3.14313892]
# Category: Unknown, Pair: ('#3', '#6'), P-value: 0.7238, CI Group1: [5.13707769 5.25994688], CI Group2: [5.14758827 5.28087676]
# Category: Unknown, Pair: ('#3', '#7'), P-value: 0.0002, CI Group1: [5.13875491 5.26052382], CI Group2: [5.61409393 5.75554088]
# Category: Unknown, Pair: ('#3', '#8'), P-value: 0.0002, CI Group1: [5.13644439 5.26059083], CI Group2: [4.54797355 4.67179602]
# Category: Unknown, Pair: ('#3', '#9'), P-value: 0.0002, CI Group1: [5.13797076 5.26004069], CI Group2: [8.90541408 9.13640703]
# Category: Unknown, Pair: ('#4', '#5'), P-value: 0.0002, CI Group1: [4.60748242 4.72942305], CI Group2: [3.06665533 3.14463527]
# Category: Unknown, Pair: ('#4', '#6'), P-value: 0.0002, CI Group1: [4.60745245 4.72976894], CI Group2: [5.1495877  5.28235771]
# Category: Unknown, Pair: ('#4', '#7'), P-value: 0.0002, CI Group1: [4.60697165 4.72847908], CI Group2: [5.61285759 5.75808583]
# Category: Unknown, Pair: ('#4', '#8'), P-value: 0.1746, CI Group1: [4.60814084 4.72979966], CI Group2: [4.54940241 4.67230898]
# Category: Unknown, Pair: ('#4', '#9'), P-value: 0.0002, CI Group1: [4.60864786 4.72853904], CI Group2: [8.90371783 9.13644209]
# Category: Unknown, Pair: ('#5', '#6'), P-value: 0.0002, CI Group1: [3.06648444 3.14387094], CI Group2: [5.14907023 5.28118256]
# Category: Unknown, Pair: ('#5', '#7'), P-value: 0.0002, CI Group1: [3.06612821 3.14473856], CI Group2: [5.61466247 5.75731187]
# Category: Unknown, Pair: ('#5', '#8'), P-value: 0.0002, CI Group1: [3.06711359 3.14446565], CI Group2: [4.54971261 4.67256142]
# Category: Unknown, Pair: ('#5', '#9'), P-value: 0.0002, CI Group1: [3.06578771 3.14479213], CI Group2: [8.90627061 9.13692365]
# Category: Unknown, Pair: ('#6', '#7'), P-value: 0.0002, CI Group1: [5.14899979 5.27960679], CI Group2: [5.614262   5.75734023]
# Category: Unknown, Pair: ('#6', '#8'), P-value: 0.0002, CI Group1: [5.15005809 5.2800221 ], CI Group2: [4.54855017 4.67215222]
# Category: Unknown, Pair: ('#6', '#9'), P-value: 0.0002, CI Group1: [5.15083062 5.28140925], CI Group2: [8.90324749 9.13509502]
# Category: Unknown, Pair: ('#7', '#8'), P-value: 0.0002, CI Group1: [5.6134455  5.75699405], CI Group2: [4.54868338 4.67057213]
# Category: Unknown, Pair: ('#7', '#9'), P-value: 0.0002, CI Group1: [5.61307096 5.75612152], CI Group2: [8.90542642 9.13875311]
# Category: Unknown, Pair: ('#8', '#9'), P-value: 0.0002, CI Group1: [4.54815165 4.67014528], CI Group2: [8.90537089 9.13532051]
# Category: Targeting/Advertising, Pair: ('#1', '#2'), P-value: 0.0002, CI Group1: [3.45628507 3.53545641], CI Group2: [3.30999665 3.38729647]
# Category: Targeting/Advertising, Pair: ('#1', '#3'), P-value: 0.0002, CI Group1: [3.45516177 3.53501281], CI Group2: [3.64889636 3.72915675]
# Category: Targeting/Advertising, Pair: ('#1', '#4'), P-value: 0.0002, CI Group1: [3.45539469 3.53499058], CI Group2: [3.33144005 3.40848815]
# Category: Targeting/Advertising, Pair: ('#1', '#5'), P-value: 0.0002, CI Group1: [3.45520465 3.5352452 ], CI Group2: [2.23543446 2.31684044]
# Category: Targeting/Advertising, Pair: ('#1', '#6'), P-value: 0.0002, CI Group1: [3.45560749 3.53549982], CI Group2: [3.58834956 3.66899208]
# Category: Targeting/Advertising, Pair: ('#1', '#7'), P-value: 0.0002, CI Group1: [3.45528988 3.53473701], CI Group2: [3.82194513 3.90824893]
# Category: Targeting/Advertising, Pair: ('#1', '#8'), P-value: 0.0002, CI Group1: [3.45588329 3.53518221], CI Group2: [3.3335027  3.40911972]
# Category: Targeting/Advertising, Pair: ('#1', '#9'), P-value: 0.0002, CI Group1: [3.45605268 3.53501281], CI Group2: [5.03328838 5.14054834]
# Category: Targeting/Advertising, Pair: ('#2', '#3'), P-value: 0.0002, CI Group1: [3.30903433 3.38776672], CI Group2: [3.64877786 3.72991284]
# Category: Targeting/Advertising, Pair: ('#2', '#4'), P-value: 0.4446, CI Group1: [3.30887945 3.38812682], CI Group2: [3.33175578 3.40866627]
# Category: Targeting/Advertising, Pair: ('#2', '#5'), P-value: 0.0002, CI Group1: [3.30966003 3.38805692], CI Group2: [2.23557761 2.31726869]
# Category: Targeting/Advertising, Pair: ('#2', '#6'), P-value: 0.0002, CI Group1: [3.309707   3.38798982], CI Group2: [3.58903626 3.66999079]
# Category: Targeting/Advertising, Pair: ('#2', '#7'), P-value: 0.0002, CI Group1: [3.30858756 3.38799038], CI Group2: [3.82124978 3.9083852 ]
# Category: Targeting/Advertising, Pair: ('#2', '#8'), P-value: 0.4248, CI Group1: [3.30957168 3.3889527 ], CI Group2: [3.33267819 3.4087494 ]
# Category: Targeting/Advertising, Pair: ('#2', '#9'), P-value: 0.0002, CI Group1: [3.30966227 3.38841534], CI Group2: [5.03157548 5.14165593]
# Category: Targeting/Advertising, Pair: ('#3', '#4'), P-value: 0.0002, CI Group1: [3.64838123 3.72967238], CI Group2: [3.33133573 3.4081996 ]
# Category: Targeting/Advertising, Pair: ('#3', '#5'), P-value: 0.0002, CI Group1: [3.6487972  3.72907941], CI Group2: [2.23509806 2.3173176 ]
# Category: Targeting/Advertising, Pair: ('#3', '#6'), P-value: 0.0428, CI Group1: [3.64772628 3.72999018], CI Group2: [3.58811446 3.66889412]
# Category: Targeting/Advertising, Pair: ('#3', '#7'), P-value: 0.0002, CI Group1: [3.64901634 3.73056481], CI Group2: [3.82094004 3.90739703]
# Category: Targeting/Advertising, Pair: ('#3', '#8'), P-value: 0.0002, CI Group1: [3.64840056 3.72901793], CI Group2: [3.3327882  3.41001231]
# Category: Targeting/Advertising, Pair: ('#3', '#9'), P-value: 0.0002, CI Group1: [3.64812292 3.72965403], CI Group2: [5.03321111 5.14074456]
# Category: Targeting/Advertising, Pair: ('#4', '#5'), P-value: 0.0002, CI Group1: [3.33066986 3.40857748], CI Group2: [2.23600706 2.31774586]
# Category: Targeting/Advertising, Pair: ('#4', '#6'), P-value: 0.0002, CI Group1: [3.33057997 3.40984208], CI Group2: [3.58877912 3.66926735]
# Category: Targeting/Advertising, Pair: ('#4', '#7'), P-value: 0.0002, CI Group1: [3.33131187 3.40979769], CI Group2: [3.82103669 3.90724675]
# Category: Targeting/Advertising, Pair: ('#4', '#8'), P-value: 0.969, CI Group1: [3.33117925 3.40775569], CI Group2: [3.33372544 3.40826962]
# Category: Targeting/Advertising, Pair: ('#4', '#9'), P-value: 0.0002, CI Group1: [3.33129134 3.40777789], CI Group2: [5.03446908 5.14192942]
# Category: Targeting/Advertising, Pair: ('#5', '#6'), P-value: 0.0002, CI Group1: [2.23576848 2.31736413], CI Group2: [3.5879778  3.66955977]
# Category: Targeting/Advertising, Pair: ('#5', '#7'), P-value: 0.0002, CI Group1: [2.2358162  2.31693468], CI Group2: [3.8206506  3.90764878]
# Category: Targeting/Advertising, Pair: ('#5', '#8'), P-value: 0.0002, CI Group1: [2.23495729 2.31650642], CI Group2: [3.33326744 3.40842265]
# Category: Targeting/Advertising, Pair: ('#5', '#9'), P-value: 0.0002, CI Group1: [2.23562533 2.31664957], CI Group2: [5.03342172 5.14060971]
# Category: Targeting/Advertising, Pair: ('#6', '#7'), P-value: 0.0002, CI Group1: [3.58811544 3.66965871], CI Group2: [3.82173155 3.90811267]
# Category: Targeting/Advertising, Pair: ('#6', '#8'), P-value: 0.0002, CI Group1: [3.58821291 3.66918752], CI Group2: [3.33274409 3.40883599]
# Category: Targeting/Advertising, Pair: ('#6', '#9'), P-value: 0.0002, CI Group1: [3.58882026 3.67050068], CI Group2: [5.03287891 5.13962371]
# Category: Targeting/Advertising, Pair: ('#7', '#8'), P-value: 0.0002, CI Group1: [3.82095889 3.90786381], CI Group2: [3.3324402 3.4093381]
# Category: Targeting/Advertising, Pair: ('#7', '#9'), P-value: 0.0002, CI Group1: [3.8206506  3.90616242], CI Group2: [5.03345505 5.14162374]
# Category: Targeting/Advertising, Pair: ('#8', '#9'), P-value: 0.0002, CI Group1: [3.33304906 3.41003409], CI Group2: [5.03265012 5.14098698]
# Category: Performance, Pair: ('#1', '#2'), P-value: 0.1072, CI Group1: [2.65336856 2.69926486], CI Group2: [2.62767497 2.67257256]
# Category: Performance, Pair: ('#1', '#3'), P-value: 0.06, CI Group1: [2.65332185 2.69907859], CI Group2: [2.68453128 2.73102427]
# Category: Performance, Pair: ('#1', '#4'), P-value: 0.8618, CI Group1: [2.65297092 2.69935829], CI Group2: [2.64960218 2.6971957 ]
# Category: Performance, Pair: ('#1', '#5'), P-value: 0.0002, CI Group1: [2.65311048 2.69924092], CI Group2: [1.68686084 1.73411165]
# Category: Performance, Pair: ('#1', '#6'), P-value: 0.2072, CI Group1: [2.65308829 2.69872767], CI Group2: [2.67448919 2.71979733]
# Category: Performance, Pair: ('#1', '#7'), P-value: 0.003, CI Group1: [2.65390634 2.69879773], CI Group2: [2.70093    2.74803374]
# Category: Performance, Pair: ('#1', '#8'), P-value: 0.226, CI Group1: [2.65304216 2.69926544], CI Group2: [2.6333783  2.67946168]
# Category: Performance, Pair: ('#1', '#9'), P-value: 0.0002, CI Group1: [2.65343922 2.69917202], CI Group2: [2.83687038 2.88297713]
# Category: Performance, Pair: ('#2', '#3'), P-value: 0.0004, CI Group1: [2.62779632 2.67279098], CI Group2: [2.68484439 2.73086575]
# Category: Performance, Pair: ('#2', '#4'), P-value: 0.1682, CI Group1: [2.62728729 2.67327574], CI Group2: [2.64989718 2.69614179]
# Category: Performance, Pair: ('#2', '#5'), P-value: 0.0002, CI Group1: [2.62752936 2.67310647], CI Group2: [1.68692557 1.73436893]
# Category: Performance, Pair: ('#2', '#6'), P-value: 0.0058, CI Group1: [2.628039   2.67262049], CI Group2: [2.67457662 2.71898355]
# Category: Performance, Pair: ('#2', '#7'), P-value: 0.0002, CI Group1: [2.62769985 2.67313013], CI Group2: [2.70104009 2.74724504]
# Category: Performance, Pair: ('#2', '#8'), P-value: 0.6986, CI Group1: [2.62781998 2.67332549], CI Group2: [2.63372042 2.67946045]
# Category: Performance, Pair: ('#2', '#9'), P-value: 0.0002, CI Group1: [2.62765071 2.6726933 ], CI Group2: [2.83660744 2.88320296]
# Category: Performance, Pair: ('#3', '#4'), P-value: 0.0428, CI Group1: [2.68473237 2.73048485], CI Group2: [2.650631   2.69704759]
# Category: Performance, Pair: ('#3', '#5'), P-value: 0.0002, CI Group1: [2.68513623 2.73086575], CI Group2: [1.68647249 1.73462783]
# Category: Performance, Pair: ('#3', '#6'), P-value: 0.5078, CI Group1: [2.68471052 2.73097833], CI Group2: [2.67431269 2.71904898]
# Category: Performance, Pair: ('#3', '#7'), P-value: 0.3286, CI Group1: [2.6843946  2.73149366], CI Group2: [2.70125917 2.74742086]
# Category: Performance, Pair: ('#3', '#8'), P-value: 0.002, CI Group1: [2.68497939 2.73021599], CI Group2: [2.63342489 2.68027039]
# Category: Performance, Pair: ('#3', '#9'), P-value: 0.0002, CI Group1: [2.68450887 2.73084334], CI Group2: [2.83636283 2.88245126]
# Category: Performance, Pair: ('#4', '#5'), P-value: 0.0002, CI Group1: [2.65001958 2.69743929], CI Group2: [1.68685922 1.73482362]
# Category: Performance, Pair: ('#4', '#6'), P-value: 0.1622, CI Group1: [2.64970072 2.6970482 ], CI Group2: [2.67404821 2.71946907]
# Category: Performance, Pair: ('#4', '#7'), P-value: 0.0026, CI Group1: [2.65036232 2.69721957], CI Group2: [2.70088673 2.74772867]
# Category: Performance, Pair: ('#4', '#8'), P-value: 0.3126, CI Group1: [2.650631  2.6971755], CI Group2: [2.63394175 2.67926426]
# Category: Performance, Pair: ('#4', '#9'), P-value: 0.0002, CI Group1: [2.65019034 2.69670486], CI Group2: [2.83688869 2.88288369]
# Category: Performance, Pair: ('#5', '#6'), P-value: 0.0002, CI Group1: [1.68608414 1.73398058], CI Group2: [2.67451008 2.71962247]
# Category: Performance, Pair: ('#5', '#7'), P-value: 0.0002, CI Group1: [1.68666667 1.73372168], CI Group2: [2.70119345 2.74777084]
# Category: Performance, Pair: ('#5', '#8'), P-value: 0.0002, CI Group1: [1.68660194 1.73404531], CI Group2: [2.63325445 2.67916616]
# Category: Performance, Pair: ('#5', '#9'), P-value: 0.0002, CI Group1: [1.68679612 1.73450162], CI Group2: [2.83655063 2.88292172]
# Category: Performance, Pair: ('#6', '#7'), P-value: 0.0926, CI Group1: [2.67475257 2.71860965], CI Group2: [2.70160916 2.74783766]
# Category: Performance, Pair: ('#6', '#8'), P-value: 0.016, CI Group1: [2.67442266 2.71927002], CI Group2: [2.63384181 2.67946045]
# Category: Performance, Pair: ('#6', '#9'), P-value: 0.0002, CI Group1: [2.67402677 2.71913751], CI Group2: [2.83619333 2.88303347]
# Category: Performance, Pair: ('#7', '#8'), P-value: 0.0002, CI Group1: [2.70145635 2.74746522], CI Group2: [2.63401594 2.67970632]
# Category: Performance, Pair: ('#7', '#9'), P-value: 0.0002, CI Group1: [2.70156589 2.74761803], CI Group2: [2.83660744 2.88247004]
# Category: Performance, Pair: ('#8', '#9'), P-value: 0.0002, CI Group1: [2.63384427 2.6795095 ], CI Group2: [2.83649476 2.88297713]
# Category: Functionality, Pair: ('#1', '#2'), P-value: 0.1078, CI Group1: [1.86992468 1.91035732], CI Group2: [1.8472915  1.88649809]
# Category: Functionality, Pair: ('#1', '#3'), P-value: 0.0076, CI Group1: [1.86998131 1.9103007 ], CI Group2: [1.90958667 1.94988483]
# Category: Functionality, Pair: ('#1', '#4'), P-value: 0.7558, CI Group1: [1.87003794 1.91001755], CI Group2: [1.87487153 1.9158052 ]
# Category: Functionality, Pair: ('#1', '#5'), P-value: 0.0002, CI Group1: [1.86964154 1.90996093], CI Group2: [1.70944219 1.74695722]
# Category: Functionality, Pair: ('#1', '#6'), P-value: 0.3324, CI Group1: [1.86992468 1.91018744], CI Group2: [1.85796767 1.89582287]
# Category: Functionality, Pair: ('#1', '#7'), P-value: 0.0102, CI Group1: [1.87037771 1.91058384], CI Group2: [1.90925414 1.94793031]
# Category: Functionality, Pair: ('#1', '#8'), P-value: 0.0184, CI Group1: [1.86981143 1.91018886], CI Group2: [1.8356994  1.87561634]
# Category: Functionality, Pair: ('#1', '#9'), P-value: 0.0002, CI Group1: [1.87003653 1.91035732], CI Group2: [2.15732224 2.19991928]
# Category: Functionality, Pair: ('#2', '#3'), P-value: 0.0002, CI Group1: [1.8472335  1.88725206], CI Group2: [1.9097398  1.94952921]
# Category: Functionality, Pair: ('#2', '#4'), P-value: 0.0594, CI Group1: [1.84705951 1.88707807], CI Group2: [1.87445474 1.91610397]
# Category: Functionality, Pair: ('#2', '#5'), P-value: 0.0002, CI Group1: [1.84752349 1.88690552], CI Group2: [1.70936701 1.74718088]
# Category: Functionality, Pair: ('#2', '#6'), P-value: 0.4998, CI Group1: [1.8472335  1.88754205], CI Group2: [1.85741415 1.89527186]
# Category: Functionality, Pair: ('#2', '#7'), P-value: 0.0002, CI Group1: [1.84682751 1.88678808], CI Group2: [1.90988378 1.9480759 ]
# Category: Functionality, Pair: ('#2', '#8'), P-value: 0.406, CI Group1: [1.8471755  1.88707952], CI Group2: [1.8356407  1.87514675]
# Category: Functionality, Pair: ('#2', '#9'), P-value: 0.0002, CI Group1: [1.8471175  1.88667208], CI Group2: [2.1571764 2.1999202]
# Category: Functionality, Pair: ('#3', '#4'), P-value: 0.0174, CI Group1: [1.90933482 1.94978232], CI Group2: [1.87421422 1.91538841]
# Category: Functionality, Pair: ('#3', '#5'), P-value: 0.0002, CI Group1: [1.90958793 1.95013668], CI Group2: [1.70936701 1.74703052]
# Category: Functionality, Pair: ('#3', '#6'), P-value: 0.0004, CI Group1: [1.90958793 1.95003544], CI Group2: [1.85766643 1.89532082]
# Category: Functionality, Pair: ('#3', '#7'), P-value: 0.9452, CI Group1: [1.90968791 1.94983295], CI Group2: [1.90964114 1.94764036]
# Category: Functionality, Pair: ('#3', '#8'), P-value: 0.0002, CI Group1: [1.90958667 1.94983421], CI Group2: [1.83564217 1.87532431]
# Category: Functionality, Pair: ('#3', '#9'), P-value: 0.0002, CI Group1: [1.9090817  1.95034044], CI Group2: [2.15732316 2.1991855 ]
# Category: Functionality, Pair: ('#4', '#5'), P-value: 0.0002, CI Group1: [1.87451449 1.91538691], CI Group2: [1.70936701 1.74688017]
# Category: Functionality, Pair: ('#4', '#6'), P-value: 0.1974, CI Group1: [1.87421422 1.91556618], CI Group2: [1.8574154  1.89491917]
# Category: Functionality, Pair: ('#4', '#7'), P-value: 0.0176, CI Group1: [1.87415596 1.91532716], CI Group2: [1.90988378 1.94802858]
# Category: Functionality, Pair: ('#4', '#8'), P-value: 0.0068, CI Group1: [1.87433523 1.91586495], CI Group2: [1.83570087 1.87567504]
# Category: Functionality, Pair: ('#4', '#9'), P-value: 0.0002, CI Group1: [1.87385569 1.91562593], CI Group2: [2.15739562 2.19970007]
# Category: Functionality, Pair: ('#5', '#6'), P-value: 0.0002, CI Group1: [1.70899113 1.74658134], CI Group2: [1.85791746 1.8952204 ]
# Category: Functionality, Pair: ('#5', '#7'), P-value: 0.0002, CI Group1: [1.70861525 1.74650616], CI Group2: [1.90998204 1.94802737]
# Category: Functionality, Pair: ('#5', '#8'), P-value: 0.0002, CI Group1: [1.70951737 1.74718275], CI Group2: [1.8354646  1.87514675]
# Category: Functionality, Pair: ('#5', '#9'), P-value: 0.0002, CI Group1: [1.70929184 1.74718088], CI Group2: [2.15669944 2.19962577]
# Category: Functionality, Pair: ('#6', '#7'), P-value: 0.0002, CI Group1: [1.85776684 1.89542248], CI Group2: [1.90939972 1.94827001]
# Category: Functionality, Pair: ('#6', '#8'), P-value: 0.1382, CI Group1: [1.85816724 1.89517145], CI Group2: [1.83605306 1.87555764]
# Category: Functionality, Pair: ('#6', '#9'), P-value: 0.0002, CI Group1: [1.85781579 1.89547269], CI Group2: [2.15728463 2.19984682]
# Category: Functionality, Pair: ('#7', '#8'), P-value: 0.0002, CI Group1: [1.90969088 1.94812442], CI Group2: [1.83575957 1.87514675]
# Category: Functionality, Pair: ('#7', '#9'), P-value: 0.0002, CI Group1: [1.91007789 1.94822148], CI Group2: [2.1571388  2.19958908]
# Category: Functionality, Pair: ('#8', '#9'), P-value: 0.0002, CI Group1: [1.8355233  1.87532285], CI Group2: [2.15724886 2.19973767]
# Category: Strictly Necessary, Pair: ('#1', '#2'), P-value: 0.2538, CI Group1: [1.54539524 1.58631438], CI Group2: [1.52486317 1.56973101]
# Category: Strictly Necessary, Pair: ('#1', '#3'), P-value: 0.7662, CI Group1: [1.54543058 1.58685803], CI Group2: [1.54190457 1.58081923]
# Category: Strictly Necessary, Pair: ('#1', '#4'), P-value: 0.247, CI Group1: [1.54499656 1.58736545], CI Group2: [1.52511223 1.57011535]
# Category: Strictly Necessary, Pair: ('#1', '#5'), P-value: 0.1652, CI Group1: [1.54539524 1.5864956 ], CI Group2: [1.52259175 1.56613439]
# Category: Strictly Necessary, Pair: ('#1', '#6'), P-value: 0.5182, CI Group1: [1.54496031 1.58693143], CI Group2: [1.53529314 1.57604894]
# Category: Strictly Necessary, Pair: ('#1', '#7'), P-value: 0.6656, CI Group1: [1.54506814 1.58729386], CI Group2: [1.55147998 1.59344541]
# Category: Strictly Necessary, Pair: ('#1', '#8'), P-value: 0.0184, CI Group1: [1.54546772 1.58653184], CI Group2: [1.50629239 1.55373116]
# Category: Strictly Necessary, Pair: ('#1', '#9'), P-value: 0.0002, CI Group1: [1.54543148 1.58656808], CI Group2: [1.61451693 1.65285154]
# Category: Strictly Necessary, Pair: ('#2', '#3'), P-value: 0.3692, CI Group1: [1.52490008 1.56947895], CI Group2: [1.5416998  1.58041055]
# Category: Strictly Necessary, Pair: ('#2', '#4'), P-value: 0.9904, CI Group1: [1.52472003 1.56944384], CI Group2: [1.52518674 1.57048239]
# Category: Strictly Necessary, Pair: ('#2', '#5'), P-value: 0.845, CI Group1: [1.52504231 1.57020003], CI Group2: [1.52291191 1.56649458]
# Category: Strictly Necessary, Pair: ('#2', '#6'), P-value: 0.612, CI Group1: [1.52490008 1.5700911 ], CI Group2: [1.53539335 1.57655003]
# Category: Strictly Necessary, Pair: ('#2', '#7'), P-value: 0.111, CI Group1: [1.52518725 1.56969591], CI Group2: [1.5519618 1.5937908]
# Category: Strictly Necessary, Pair: ('#2', '#8'), P-value: 0.3062, CI Group1: [1.52522415 1.57037917], CI Group2: [1.5064431 1.5536558]
# Category: Strictly Necessary, Pair: ('#2', '#9'), P-value: 0.0002, CI Group1: [1.5254033  1.57005509], CI Group2: [1.61492744 1.65229342]
# Category: Strictly Necessary, Pair: ('#3', '#4'), P-value: 0.3836, CI Group1: [1.54163183 1.58054649], CI Group2: [1.5255547  1.56948983]
# Category: Strictly Necessary, Pair: ('#3', '#5'), P-value: 0.2694, CI Group1: [1.54173379 1.58003755], CI Group2: [1.5223116  1.56665566]
# Category: Strictly Necessary, Pair: ('#3', '#6'), P-value: 0.7016, CI Group1: [1.5418366  1.58037656], CI Group2: [1.53515951 1.57631619]
# Category: Strictly Necessary, Pair: ('#3', '#7'), P-value: 0.4582, CI Group1: [1.54176862 1.5804114 ], CI Group2: [1.55182537 1.59278831]
# Category: Strictly Necessary, Pair: ('#3', '#8'), P-value: 0.0358, CI Group1: [1.54166582 1.58136215], CI Group2: [1.50636775 1.55259985]
# Category: Strictly Necessary, Pair: ('#3', '#9'), P-value: 0.0002, CI Group1: [1.54163183 1.58037741], CI Group2: [1.61457568 1.65241019]
# Category: Strictly Necessary, Pair: ('#4', '#5'), P-value: 0.8392, CI Group1: [1.52533392 1.56989366], CI Group2: [1.52283087 1.56669468]
# Category: Strictly Necessary, Pair: ('#4', '#6'), P-value: 0.6078, CI Group1: [1.52500184 1.57055782], CI Group2: [1.53535911 1.57591532]
# Category: Strictly Necessary, Pair: ('#4', '#7'), P-value: 0.1072, CI Group1: [1.52496504 1.57022666], CI Group2: [1.55199807 1.59389355]
# Category: Strictly Necessary, Pair: ('#4', '#8'), P-value: 0.3038, CI Group1: [1.52551698 1.57048423], CI Group2: [1.50670686 1.55275057]
# Category: Strictly Necessary, Pair: ('#4', '#9'), P-value: 0.0002, CI Group1: [1.52518674 1.56919454], CI Group2: [1.61463443 1.65179405]
# Category: Strictly Necessary, Pair: ('#5', '#6'), P-value: 0.454, CI Group1: [1.52279185 1.56685576], CI Group2: [1.53522549 1.57608318]
# Category: Strictly Necessary, Pair: ('#5', '#7'), P-value: 0.059, CI Group1: [1.52235162 1.56657462], CI Group2: [1.55210082 1.59292647]
# Category: Strictly Necessary, Pair: ('#5', '#8'), P-value: 0.4026, CI Group1: [1.52267179 1.56629747], CI Group2: [1.50674454 1.55354277]
# Category: Strictly Necessary, Pair: ('#5', '#9'), P-value: 0.0002, CI Group1: [1.52279085 1.56605635], CI Group2: [1.6147512  1.65285081]
# Category: Strictly Necessary, Pair: ('#6', '#7'), P-value: 0.2796, CI Group1: [1.53485886 1.57634959], CI Group2: [1.55227438 1.59351449]
# Category: Strictly Necessary, Pair: ('#6', '#8'), P-value: 0.101, CI Group1: [1.53569317 1.57604894], CI Group2: [1.50723436 1.5538442 ]
# Category: Strictly Necessary, Pair: ('#6', '#9'), P-value: 0.0002, CI Group1: [1.53535828 1.57648238], CI Group2: [1.61472256 1.65211644]
# Category: Strictly Necessary, Pair: ('#7', '#8'), P-value: 0.003, CI Group1: [1.55192899 1.59378994], CI Group2: [1.50614167 1.55346741]
# Category: Strictly Necessary, Pair: ('#7', '#9'), P-value: 0.0002, CI Group1: [1.55154906 1.59347995], CI Group2: [1.61437006 1.65214582]
# Category: Strictly Necessary, Pair: ('#8', '#9'), P-value: 0.0002, CI Group1: [1.50674359 1.55346741], CI Group2: [1.61466381 1.65238081]

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import itertools
import os
from scipy.stats import permutation_test

# Load the dataset
path = os.getcwd() + "/datasets-stats/s3_cat_cookies_vs_profile.csv"
df = pd.read_csv(path) 

# Get unique categories
categories = df['category'].unique()

def bootstrap_ci(data, statistic, alpha):
    """Compute bootstrap confidence interval for given data and statistic."""
    bs_replicates = np.empty(10000)
    
    for i in range(10000):
        bs_sample = np.random.choice(data, len(data))
        bs_replicates[i] = statistic(bs_sample)
        
    return np.percentile(bs_replicates, [100 * alpha / 2., 100 * (1 - alpha / 2.)])

def test_statistic(a, b):
    """Statistic for permutation test."""
    return np.mean(a) - np.mean(b)

def cohen_d(x, y):
    """Calculate Cohen's d for effect size."""
    nx = len(x)
    ny = len(y)
    dof = nx + ny - 2
    return (np.mean(x) - np.mean(y)) / np.sqrt(((nx-1)*np.std(x, ddof=1) ** 2 + (ny-1)*np.std(y, ddof=1) ** 2) / dof)

# Iterate over each category
for category in categories:
    # Get unique aliases within this category
    aliases_in_category = df[df['category'] == category]['alias'].unique()

    # Generate all pairs of aliases
    pairs = list(itertools.combinations(aliases_in_category, 2))

    # Perform permutation test for each pair
    for pair in pairs:
        group1 = df[(df['alias'] == pair[0]) & (df['category'] == category)]['ct'].to_numpy()
        group2 = df[(df['alias'] == pair[1]) & (df['category'] == category)]['ct'].to_numpy()

        result = permutation_test((group1, group2), 
                                  test_statistic,
                                  vectorized=False,
                                  alternative='two-sided',
                                  permutation_type='independent')

        # Calculate bootstrap confidence intervals for the mean
        ci_group1 = bootstrap_ci(group1, np.mean, 0.05)
        ci_group2 = bootstrap_ci(group2, np.mean, 0.05)
        
        # Calculate Cohen's d for effect size
        d = cohen_d(group1, group2)

        print(f'Category: {category}, Pair: {pair}, P-value: {result.pvalue}, CI Group1: {ci_group1}, CI Group2: {ci_group2}, Cohen\'s d: {d}')
# Out:
# Category: Unknown, Pair: ('#1', '#2'), P-value: 0.0002, CI Group1: [4.89445378 5.01297277], CI Group2: [4.69278195 4.82008563], Cohen's d: 0.024235528191900585
# Category: Unknown, Pair: ('#1', '#3'), P-value: 0.0002, CI Group1: [4.89309583 5.01310604], CI Group2: [5.13887827 5.26017813], Cohen's d: -0.030371356687908174
# Category: Unknown, Pair: ('#1', '#4'), P-value: 0.0002, CI Group1: [4.89299143 5.01131531], CI Group2: [4.60674756 4.72900409], Cohen's d: 0.03588193715045524
# Category: Unknown, Pair: ('#1', '#5'), P-value: 0.0002, CI Group1: [4.89404358 5.01306199], CI Group2: [3.06634841 3.14516324], Cohen's d: 0.2794122484898809
# Category: Unknown, Pair: ('#1', '#6'), P-value: 0.0002, CI Group1: [4.89238501 5.01058931], CI Group2: [5.15071244 5.28018101], Cohen's d: -0.030688687142356275
# Category: Unknown, Pair: ('#1', '#7'), P-value: 0.0002, CI Group1: [4.89506501 5.01278285], CI Group2: [5.61412298 5.75815673], Cohen's d: -0.08194319696497586
# Category: Unknown, Pair: ('#1', '#8'), P-value: 0.0002, CI Group1: [4.89450228 5.01087068], CI Group2: [4.54812295 4.67145675], Cohen's d: 0.04311970784589991
# Category: Unknown, Pair: ('#1', '#9'), P-value: 0.0002, CI Group1: [4.894205   5.01051527], CI Group2: [8.90450397 9.13467965], Cohen's d: -0.2843930289044034
# Category: Unknown, Pair: ('#2', '#3'), P-value: 0.0002, CI Group1: [4.69368341 4.82181593], CI Group2: [5.1391951  5.26051145], Cohen's d: -0.052909691866580455
# Category: Unknown, Pair: ('#2', '#4'), P-value: 0.0512, CI Group1: [4.69306714 4.82059806], CI Group2: [4.6072276  4.72918397], Cohen's d: 0.01077194333559359
# Category: Unknown, Pair: ('#2', '#5'), P-value: 0.0002, CI Group1: [4.69251031 4.8207922 ], CI Group2: [3.06728363 3.14351938], Cohen's d: 0.23786683976235612
# Category: Unknown, Pair: ('#2', '#6'), P-value: 0.0002, CI Group1: [4.69360929 4.82037232], CI Group2: [5.14920343 5.2801266 ], Cohen's d: -0.05219958296489812
# Category: Unknown, Pair: ('#2', '#7'), P-value: 0.0002, CI Group1: [4.69285607 4.81921277], CI Group2: [5.61384631 5.75735268], Cohen's d: -0.10125140659441033
# Category: Unknown, Pair: ('#2', '#8'), P-value: 0.0016, CI Group1: [4.69449645 4.82145663], CI Group2: [4.54749113 4.66946894], Cohen's d: 0.017876378669983692
# Category: Unknown, Pair: ('#2', '#9'), P-value: 0.0002, CI Group1: [4.69392533 4.82074856], CI Group2: [8.90364126 9.13513933], Cohen's d: -0.2947726435820929
# Category: Unknown, Pair: ('#3', '#4'), P-value: 0.0002, CI Group1: [5.13799791 5.26071487], CI Group2: [4.60728606 4.72976856], Cohen's d: 0.06466962238512344
# Category: Unknown, Pair: ('#3', '#5'), P-value: 0.0002, CI Group1: [5.13820512 5.25999945], CI Group2: [3.06623023 3.14502848], Cohen's d: 0.2982549149352193
# Category: Unknown, Pair: ('#3', '#6'), P-value: 0.7236, CI Group1: [5.13786115 5.25942216], CI Group2: [5.15057823 5.28269156], Cohen's d: -0.001787588503077802
# Category: Unknown, Pair: ('#3', '#7'), P-value: 0.0002, CI Group1: [5.13794156 5.25934141], CI Group2: [5.61386015 5.75522271], Cohen's d: -0.053083296790883916
# Category: Unknown, Pair: ('#3', '#8'), P-value: 0.0002, CI Group1: [5.13922259 5.26082587], CI Group2: [4.54863885 4.67170955], Cohen's d: 0.07159131824605697
# Category: Unknown, Pair: ('#3', '#9'), P-value: 0.0002, CI Group1: [5.13772404 5.25961528], CI Group2: [8.90448322 9.13857193], Cohen's d: -0.2675585461031895
# Category: Unknown, Pair: ('#4', '#5'), P-value: 0.0002, CI Group1: [4.6075866  4.72858401], CI Group2: [3.06709616 3.14461911], Cohen's d: 0.2320512062311896
# Category: Unknown, Pair: ('#4', '#6'), P-value: 0.0002, CI Group1: [4.60643278 4.73038276], CI Group2: [5.15077954 5.28136952], Cohen's d: -0.06331631240204554
# Category: Unknown, Pair: ('#4', '#7'), P-value: 0.0002, CI Group1: [4.60694243 4.72816655], CI Group2: [5.6135285  5.75718668], Cohen's d: -0.11266686435799404
# Category: Unknown, Pair: ('#4', '#8'), P-value: 0.178, CI Group1: [4.60773762 4.72933349], CI Group2: [4.54924234 4.66952965], Cohen's d: 0.0072865868195012016
# Category: Unknown, Pair: ('#4', '#9'), P-value: 0.0002, CI Group1: [4.60735614 4.72854091], CI Group2: [8.90218397 9.13671021], Cohen's d: -0.3027430322325304
# Category: Unknown, Pair: ('#5', '#6'), P-value: 0.0002, CI Group1: [3.06678966 3.14463569], CI Group2: [5.14823961 5.28022007], Cohen's d: -0.27904900233702046
# Category: Unknown, Pair: ('#5', '#7'), P-value: 0.0002, CI Group1: [3.06577028 3.14463569], CI Group2: [5.61384597 5.75435157], Cohen's d: -0.32254855494920764
# Category: Unknown, Pair: ('#5', '#8'), P-value: 0.0002, CI Group1: [3.06679094 3.14400612], CI Group2: [4.54925337 4.67238368], Cohen's d: -0.22158867143914596
# Category: Unknown, Pair: ('#5', '#9'), P-value: 0.0002, CI Group1: [3.06650145 3.1446714 ], CI Group2: [8.90594556 9.13342542], Cohen's d: -0.4205411043772862
# Category: Unknown, Pair: ('#6', '#7'), P-value: 0.0002, CI Group1: [5.15028578 5.28147702], CI Group2: [5.61254427 5.75691832], Cohen's d: -0.0494392908772714
# Category: Unknown, Pair: ('#6', '#8'), P-value: 0.0002, CI Group1: [5.15016459 5.28141025], CI Group2: [4.54725415 4.66945532], Cohen's d: 0.06994623848721596
# Category: Unknown, Pair: ('#6', '#9'), P-value: 0.0002, CI Group1: [5.14996294 5.28166264], CI Group2: [8.90631212 9.13376871], Cohen's d: -0.2636279620280404
# Category: Unknown, Pair: ('#7', '#8'), P-value: 0.0002, CI Group1: [5.61211717 5.7578109 ], CI Group2: [4.54775424 4.66995503], Cohen's d: 0.11894968612521761
# Category: Unknown, Pair: ('#7', '#9'), P-value: 0.0002, CI Group1: [5.61214345 5.757989  ], CI Group2: [8.90476452 9.13699124], Cohen's d: -0.22679397580907723
# Category: Unknown, Pair: ('#8', '#9'), P-value: 0.0002, CI Group1: [4.54843205 4.67132317], CI Group2: [8.90560227 9.13442135], Cohen's d: -0.30734958360644626
# Category: Targeting/Advertising, Pair: ('#1', '#2'), P-value: 0.0002, CI Group1: [3.45512048 3.5346952 ], CI Group2: [3.30939331 3.38747596], Cohen's d: 0.03396965147467893
# Category: Targeting/Advertising, Pair: ('#1', '#3'), P-value: 0.0002, CI Group1: [3.45482457 3.53420766], CI Group2: [3.64788593 3.72919641], Cohen's d: -0.042787785635870976
# Category: Targeting/Advertising, Pair: ('#1', '#4'), P-value: 0.0002, CI Group1: [3.4554381 3.5349694], CI Group2: [3.33142451 3.40886658], Cohen's d: 0.029175116154934847
# Category: Targeting/Advertising, Pair: ('#1', '#5'), P-value: 0.0002, CI Group1: [3.45575571 3.53518221], CI Group2: [2.235815   2.31674619], Cohen's d: 0.30307642073152075
# Category: Targeting/Advertising, Pair: ('#1', '#6'), P-value: 0.0002, CI Group1: [3.45558579 3.53530819], CI Group2: [3.58887904 3.66875796], Cohen's d: -0.02938961756720632
# Category: Targeting/Advertising, Pair: ('#1', '#7'), P-value: 0.0002, CI Group1: [3.45514219 3.53552364], CI Group2: [3.82142326 3.90809382], Cohen's d: -0.07805637314339921
# Category: Targeting/Advertising, Pair: ('#1', '#8'), P-value: 0.0002, CI Group1: [3.45522635 3.53484342], CI Group2: [3.33235198 3.40811659], Cohen's d: 0.02902602701019186
# Category: Targeting/Advertising, Pair: ('#1', '#9'), P-value: 0.0002, CI Group1: [3.45482404 3.53501281], CI Group2: [5.03292436 5.1404722 ], Cohen's d: -0.26221093798450923
# Category: Targeting/Advertising, Pair: ('#2', '#3'), P-value: 0.0002, CI Group1: [3.30916965 3.38799038], CI Group2: [3.64909567 3.72973237], Cohen's d: -0.07648059570925553
# Category: Targeting/Advertising, Pair: ('#2', '#4'), P-value: 0.4346, CI Group1: [3.3101985  3.38801163], CI Group2: [3.33131298 3.40744606], Cohen's d: -0.005046637432917136
# Category: Targeting/Advertising, Pair: ('#2', '#5'), P-value: 0.0002, CI Group1: [3.30939331 3.3878355 ], CI Group2: [2.23600706 2.31607697], Cohen's d: 0.2770991258738162
# Category: Targeting/Advertising, Pair: ('#2', '#6'), P-value: 0.0002, CI Group1: [3.30966171 3.38660255], CI Group2: [3.5882134  3.66952107], Cohen's d: -0.06267120064407701
# Category: Targeting/Advertising, Pair: ('#2', '#7'), P-value: 0.0002, CI Group1: [3.3101314  3.38761015], CI Group2: [3.82103572 3.90790005], Cohen's d: -0.11067810047546517
# Category: Targeting/Advertising, Pair: ('#2', '#8'), P-value: 0.42, CI Group1: [3.3100151  3.38807929], CI Group2: [3.33309045 3.40883654], Cohen's d: -0.005319770327567246
# Category: Targeting/Advertising, Pair: ('#2', '#9'), P-value: 0.0002, CI Group1: [3.30948222 3.38720924], CI Group2: [5.03415128 5.14125972], Cohen's d: -0.28728921819162884
# Category: Targeting/Advertising, Pair: ('#3', '#4'), P-value: 0.0002, CI Group1: [3.64869854 3.72965354], CI Group2: [3.33100224 3.4087101 ], Cohen's d: 0.071992629103105
# Category: Targeting/Advertising, Pair: ('#3', '#5'), P-value: 0.0002, CI Group1: [3.64756366 3.73006951], CI Group2: [2.23509806 2.31669728], Cohen's d: 0.33415055518828024
# Category: Targeting/Advertising, Pair: ('#3', '#6'), P-value: 0.0372, CI Group1: [3.64838073 3.72917807], CI Group2: [3.58872083 3.66891372], Cohen's d: 0.01288283092554155
# Category: Targeting/Advertising, Pair: ('#3', '#7'), P-value: 0.0002, CI Group1: [3.64923449 3.72971204], CI Group2: [3.82188666 3.90712739], Cohen's d: -0.03627415742944787
# Category: Targeting/Advertising, Pair: ('#3', '#8'), P-value: 0.0002, CI Group1: [3.64913533 3.72995548], CI Group2: [3.33267819 3.40844443], Cohen's d: 0.07199564834202397
# Category: Targeting/Advertising, Pair: ('#3', '#9'), P-value: 0.0002, CI Group1: [3.64915516 3.73078346], CI Group2: [5.03312134 5.14035175], Cohen's d: -0.22881944936138426
# Category: Targeting/Advertising, Pair: ('#4', '#5'), P-value: 0.0002, CI Group1: [3.33120256 3.40804368], CI Group2: [2.23538555 2.31774705], Cohen's d: 0.284418819196289
# Category: Targeting/Advertising, Pair: ('#4', '#6'), P-value: 0.0002, CI Group1: [3.33126581 3.40780008], CI Group2: [3.58805617 3.6702063 ], Cohen's d: -0.0581508644787084
# Category: Targeting/Advertising, Pair: ('#4', '#7'), P-value: 0.0002, CI Group1: [3.33044735 3.4084432 ], CI Group2: [3.82153923 3.90803535], Cohen's d: -0.10651169294650027
# Category: Targeting/Advertising, Pair: ('#4', '#8'), P-value: 0.9668, CI Group1: [3.33129078 3.40842101], CI Group2: [3.33243966 3.40850924], Cohen's d: -0.00025660316208246246
# Category: Targeting/Advertising, Pair: ('#4', '#9'), P-value: 0.0002, CI Group1: [3.33286723 3.40877614], CI Group2: [5.03348498 5.13998848], Cohen's d: -0.2844947435806154
# Category: Targeting/Advertising, Pair: ('#5', '#6'), P-value: 0.0002, CI Group1: [2.23543446 2.31698239], CI Group2: [3.58793862 3.66944221], Cohen's d: -0.31751366207781573
# Category: Targeting/Advertising, Pair: ('#5', '#7'), P-value: 0.0002, CI Group1: [2.23514816 2.31722098], CI Group2: [3.82074676 3.90807498], Cohen's d: -0.3513137596184976
# Category: Targeting/Advertising, Pair: ('#5', '#8'), P-value: 0.0002, CI Group1: [2.23614902 2.31636327], CI Group2: [3.33363667 3.40868623], Cohen's d: -0.28595541528021606
# Category: Targeting/Advertising, Pair: ('#5', '#9'), P-value: 0.0002, CI Group1: [2.23586272 2.31693587], CI Group2: [5.03422438 5.14097221], Cohen's d: -0.44656842135229197
# Category: Targeting/Advertising, Pair: ('#6', '#7'), P-value: 0.0002, CI Group1: [3.58870271 3.67048157], CI Group2: [3.82146191 3.90766908], Cohen's d: -0.04854176249825374
# Category: Targeting/Advertising, Pair: ('#6', '#8'), P-value: 0.0002, CI Group1: [3.58811299 3.66834604], CI Group2: [3.33281053 3.40844334], Cohen's d: 0.05810727944020768
# Category: Targeting/Advertising, Pair: ('#6', '#9'), P-value: 0.0002, CI Group1: [3.587704   3.66856106], CI Group2: [5.03327134 5.14094153], Cohen's d: -0.23844085885471017
# Category: Targeting/Advertising, Pair: ('#7', '#8'), P-value: 0.0002, CI Group1: [3.82105553 3.90722355], CI Group2: [3.33296192 3.40944757], Cohen's d: 0.10664790526892305
# Category: Targeting/Advertising, Pair: ('#7', '#9'), P-value: 0.0002, CI Group1: [3.8211918  3.90737818], CI Group2: [5.0331058  5.13989606], Cohen's d: -0.1965704140167707
# Category: Targeting/Advertising, Pair: ('#8', '#9'), P-value: 0.0002, CI Group1: [3.33341992 3.40918453], CI Group2: [5.03243913 5.14038091], Cohen's d: -0.28526798331872144
# Category: Performance, Pair: ('#1', '#2'), P-value: 0.1056, CI Group1: [2.65423275 2.69891452], CI Group2: [2.62813668 2.67274244], Cohen's d: 0.010932550773977135
# Category: Performance, Pair: ('#1', '#3'), P-value: 0.054, CI Group1: [2.65299545 2.69956791], CI Group2: [2.68423945 2.73118054], Cohen's d: -0.012854268961846176
# Category: Performance, Pair: ('#1', '#4'), P-value: 0.8686, CI Group1: [2.65406925 2.69896181], CI Group2: [2.64947978 2.69709717], Cohen's d: 0.0011542758328316482
# Category: Performance, Pair: ('#1', '#5'), P-value: 0.0002, CI Group1: [2.65385963 2.69956908], CI Group2: [1.68647249 1.73391586], Cohen's d: 0.4375310202327492
# Category: Performance, Pair: ('#1', '#6'), P-value: 0.2168, CI Group1: [2.65369555 2.69884445], CI Group2: [2.67429124 2.7193569 ], Cohen's d: -0.008436254145538346
# Category: Performance, Pair: ('#1', '#7'), P-value: 0.0036, CI Group1: [2.65290202 2.69928822], CI Group2: [2.70123672 2.74772757], Cohen's d: -0.019559900676545013
# Category: Performance, Pair: ('#1', '#8'), P-value: 0.2292, CI Group1: [2.65341586 2.69912472], CI Group2: [2.63403924 2.6797057 ], Cohen's d: 0.008253825676339577
# Category: Performance, Pair: ('#1', '#9'), P-value: 0.0002, CI Group1: [2.65306551 2.69947448], CI Group2: [2.83698165 2.88308981], Cohen's d: -0.07120883727863624
# Category: Performance, Pair: ('#2', '#3'), P-value: 0.0008, CI Group1: [2.62740742 2.67310768], CI Group2: [2.68491161 2.72985806], Cohen's d: -0.02377250630734457
# Category: Performance, Pair: ('#2', '#4'), P-value: 0.1634, CI Group1: [2.627894   2.67271757], CI Group2: [2.64967685 2.6969258 ], Cohen's d: -0.009742939105459031
# Category: Performance, Pair: ('#2', '#5'), P-value: 0.0002, CI Group1: [2.62718961 2.67283891], CI Group2: [1.68686084 1.73417638], Cohen's d: 0.4366175636872092
# Category: Performance, Pair: ('#2', '#6'), P-value: 0.0036, CI Group1: [2.62735888 2.67257317], CI Group2: [2.67376284 2.71968846], Cohen's d: -0.0193490914790566
# Category: Performance, Pair: ('#2', '#7'), P-value: 0.0002, CI Group1: [2.62762704 2.67257438], CI Group2: [2.70101873 2.7471355 ], Cohen's d: -0.030453788556889367
# Category: Performance, Pair: ('#2', '#8'), P-value: 0.7062, CI Group1: [2.62723814 2.67332488], CI Group2: [2.63411343 2.67965727], Cohen's d: -0.002705763230996256
# Category: Performance, Pair: ('#2', '#9'), P-value: 0.0002, CI Group1: [2.62752997 2.67286318], CI Group2: [2.83677553 2.88286444], Cohen's d: -0.08201028001764059
# Category: Performance, Pair: ('#3', '#4'), P-value: 0.0406, CI Group1: [2.68482255 2.73057504], CI Group2: [2.65021482 2.69746377], Cohen's d: 0.013962245181903792
# Category: Performance, Pair: ('#3', '#5'), P-value: 0.0002, CI Group1: [2.68466515 2.73077668], CI Group2: [1.68711974 1.73411003], Cohen's d: 0.439597059475512
# Category: Performance, Pair: ('#3', '#6'), P-value: 0.4984, CI Group1: [2.68488977 2.73053079], CI Group2: [2.6739168  2.71946797], Cohen's d: 0.004412249084978312
# Category: Performance, Pair: ('#3', '#7'), P-value: 0.3138, CI Group1: [2.68502364 2.73021711], CI Group2: [2.70150071 2.74728941], Cohen's d: -0.0067241175971511505
# Category: Performance, Pair: ('#3', '#8'), P-value: 0.0016, CI Group1: [2.68470996 2.7304406 ], CI Group2: [2.63403985 2.67951073], Cohen's d: 0.02112279219305731
# Category: Performance, Pair: ('#3', '#9'), P-value: 0.0002, CI Group1: [2.68462034 2.73102258], CI Group2: [2.83666332 2.88262029], Cohen's d: -0.058423391806712875
# Category: Performance, Pair: ('#4', '#5'), P-value: 0.0002, CI Group1: [2.64965176 2.69721896], CI Group2: [1.68634304 1.73411003], Cohen's d: 0.4361121814388673
# Category: Performance, Pair: ('#4', '#6'), P-value: 0.1598, CI Group1: [2.65019095 2.69707268], CI Group2: [2.67389535 2.7195114 ], Cohen's d: -0.009560127243713709
# Category: Performance, Pair: ('#4', '#7'), P-value: 0.0022, CI Group1: [2.64999449 2.69668038], CI Group2: [2.70134626 2.74724559], Cohen's d: -0.02064060108939724
# Category: Performance, Pair: ('#4', '#8'), P-value: 0.3064, CI Group1: [2.64989657 2.69709655], CI Group2: [2.63416248 2.6796076 ], Cohen's d: 0.007070017143318684
# Category: Performance, Pair: ('#4', '#9'), P-value: 0.0002, CI Group1: [2.65004407 2.69694967], CI Group2: [2.8372643  2.88308981], Cohen's d: -0.07207903279017416
# Category: Performance, Pair: ('#5', '#6'), P-value: 0.0002, CI Group1: [1.68614887 1.73436893], CI Group2: [2.67477511 2.71926947], Cohen's d: -0.4373861835925849
# Category: Performance, Pair: ('#5', '#7'), P-value: 0.0002, CI Group1: [1.68724919 1.73540453], CI Group2: [2.70174061 2.7472675 ], Cohen's d: -0.440320873085802
# Category: Performance, Pair: ('#5', '#8'), P-value: 0.0002, CI Group1: [1.68718285 1.73411165], CI Group2: [2.63350092 2.67946107], Cohen's d: -0.4392908218647407
# Category: Performance, Pair: ('#5', '#9'), P-value: 0.0002, CI Group1: [1.68672977 1.73411165], CI Group2: [2.83679525 2.88303347], Cohen's d: -0.4623443243146312
# Category: Performance, Pair: ('#6', '#7'), P-value: 0.0916, CI Group1: [2.6735429  2.71911551], CI Group2: [2.70101873 2.74711414], Cohen's d: -0.011129772986769232
# Category: Performance, Pair: ('#6', '#8'), P-value: 0.0168, CI Group1: [2.67422526 2.71922493], CI Group2: [2.63367198 2.67919129], Cohen's d: 0.01669234505428552
# Category: Performance, Pair: ('#6', '#9'), P-value: 0.0002, CI Group1: [2.67466404 2.71957684], CI Group2: [2.83715209 2.88278979], Cohen's d: -0.06284366849655482
# Category: Performance, Pair: ('#7', '#8'), P-value: 0.0002, CI Group1: [2.70097437 2.7476613 ], CI Group2: [2.63377069 2.67973084], Cohen's d: 0.027820652056260994
# Category: Performance, Pair: ('#7', '#9'), P-value: 0.0002, CI Group1: [2.70130244 2.74748658], CI Group2: [2.83702015 2.88226346], Cohen's d: -0.05166827393420209
# Category: Performance, Pair: ('#8', '#9'), P-value: 0.0002, CI Group1: [2.63391784 2.67914224], CI Group2: [2.8366821  2.88258273], Cohen's d: -0.0794469161294162
# Category: Functionality, Pair: ('#1', '#2'), P-value: 0.111, CI Group1: [1.87009457 1.91013081], CI Group2: [1.84758149 1.88702152], Cohen's d: 0.017114122178002587
# Category: Functionality, Pair: ('#1', '#3'), P-value: 0.0066, CI Group1: [1.86952687 1.91007418], CI Group2: [1.90938544 1.95023793], Cohen's d: -0.02802781793757663
# Category: Functionality, Pair: ('#1', '#4'), P-value: 0.7424, CI Group1: [1.87077411 1.91075514], CI Group2: [1.87469376 1.9152689 ], Cohen's d: -0.0034031909545329435
# Category: Functionality, Pair: ('#1', '#5'), P-value: 0.0002, CI Group1: [1.87049097 1.91069709], CI Group2: [1.70906631 1.7471057 ], Cohen's d: 0.128555630796903
# Category: Functionality, Pair: ('#1', '#6'), P-value: 0.3276, CI Group1: [1.87009457 1.91041395], CI Group2: [1.85756602 1.89517145], Cohen's d: 0.010125617196396854
# Category: Functionality, Pair: ('#1', '#7'), P-value: 0.0066, CI Group1: [1.87054618 1.9103007 ], CI Group2: [1.9100791  1.94822148], Cohen's d: -0.02782833541119107
# Category: Functionality, Pair: ('#1', '#8'), P-value: 0.0172, CI Group1: [1.87020783 1.91024548], CI Group2: [1.83552477 1.87544024], Cohen's d: 0.025817951714808354
# Category: Functionality, Pair: ('#1', '#9'), P-value: 0.0002, CI Group1: [1.87026445 1.91041395], CI Group2: [2.15732316 2.20028618], Cohen's d: -0.1766209053876059
# Category: Functionality, Pair: ('#2', '#3'), P-value: 0.0002, CI Group1: [1.84740749 1.88713606], CI Group2: [1.90948669 1.94942796], Cohen's d: -0.04476558086564126
# Category: Functionality, Pair: ('#2', '#4'), P-value: 0.0602, CI Group1: [1.84740604 1.88702007], CI Group2: [1.87379743 1.91568569], Cohen's d: -0.02055100332217625
# Category: Functionality, Pair: ('#2', '#5'), P-value: 0.0002, CI Group1: [1.84740749 1.88702007], CI Group2: [1.7088389  1.74718088], Cohen's d: 0.1118299195588397
# Category: Functionality, Pair: ('#2', '#6'), P-value: 0.503, CI Group1: [1.84705806 1.88725206], CI Group2: [1.85766643 1.89491917], Cohen's d: -0.0069217313400732165
# Category: Functionality, Pair: ('#2', '#7'), P-value: 0.0002, CI Group1: [1.84734805 1.88736805], CI Group2: [1.90954409 1.94817295], Cohen's d: -0.044851519323708
# Category: Functionality, Pair: ('#2', '#8'), P-value: 0.4118, CI Group1: [1.84700151 1.88649954], CI Group2: [1.835582   1.87573374], Cohen's d: 0.008749182419540034
# Category: Functionality, Pair: ('#2', '#9'), P-value: 0.0002, CI Group1: [1.8471175 1.8876015], CI Group2: [2.15677282 2.19925888], Cohen's d: -0.19149472792728936
# Category: Functionality, Pair: ('#3', '#4'), P-value: 0.0178, CI Group1: [1.90948669 1.94963045], CI Group2: [1.87403645 1.91550792], Cohen's d: 0.024712216951310872
# Category: Functionality, Pair: ('#3', '#5'), P-value: 0.0002, CI Group1: [1.90999165 1.95033917], CI Group2: [1.70899113 1.74695722], Cohen's d: 0.15211419331177078
# Category: Functionality, Pair: ('#3', '#6'), P-value: 0.0004, CI Group1: [1.90913233 1.9498861 ], CI Group2: [1.85776684 1.89542248], Cohen's d: 0.037931603641826184
# Category: Functionality, Pair: ('#3', '#7'), P-value: 0.9626, CI Group1: [1.90984104 1.94983295], CI Group2: [1.9095453  1.94768768], Cohen's d: 0.0006463610743172705
# Category: Functionality, Pair: ('#3', '#8'), P-value: 0.0002, CI Group1: [1.90968918 1.95049104], CI Group2: [1.8357581  1.87579244], Cohen's d: 0.05320701942879807
# Category: Functionality, Pair: ('#3', '#9'), P-value: 0.0002, CI Group1: [1.90943606 1.95033917], CI Group2: [2.15710302 2.19966338], Cohen's d: -0.15047135492642816
# Category: Functionality, Pair: ('#4', '#5'), P-value: 0.0002, CI Group1: [1.87463251 1.91520765], CI Group2: [1.70906631 1.74703052], Cohen's d: 0.1325148890993239
# Category: Functionality, Pair: ('#4', '#6'), P-value: 0.2046, CI Group1: [1.8739767  1.91568569], CI Group2: [1.85781579 1.89537102], Cohen's d: 0.013533990881545041
# Category: Functionality, Pair: ('#4', '#7'), P-value: 0.0194, CI Group1: [1.87409621 1.91592471], CI Group2: [1.90959383 1.94739652], Cohen's d: -0.024468137679386475
# Category: Functionality, Pair: ('#4', '#8'), P-value: 0.0084, CI Group1: [1.87427398 1.91568718], CI Group2: [1.83528997 1.87597   ], Cohen's d: 0.02926555708724565
# Category: Functionality, Pair: ('#4', '#9'), P-value: 0.0002, CI Group1: [1.87433373 1.91604422], CI Group2: [2.15735893 2.19981105], Cohen's d: -0.1732031426722185
# Category: Functionality, Pair: ('#5', '#6'), P-value: 0.0002, CI Group1: [1.70914148 1.74740641], CI Group2: [1.85751581 1.89517145], Cohen's d: -0.11731749826721412
# Category: Functionality, Pair: ('#5', '#7'), P-value: 0.0002, CI Group1: [1.7088389  1.74657946], CI Group2: [1.91017494 1.947883  ], Cohen's d: -0.15439098517848732
# Category: Functionality, Pair: ('#5', '#8'), P-value: 0.0002, CI Group1: [1.70906631 1.74688017], CI Group2: [1.8359342  1.87561634], Cohen's d: -0.10288413812689942
# Category: Functionality, Pair: ('#5', '#9'), P-value: 0.0002, CI Group1: [1.70906631 1.74725793], CI Group2: [2.15743323 2.19944232], Cohen's d: -0.2820730486777514
# Category: Functionality, Pair: ('#6', '#7'), P-value: 0.0002, CI Group1: [1.85781705 1.89552164], CI Group2: [1.90935119 1.94802858], Cohen's d: -0.03786050415087695
# Category: Functionality, Pair: ('#6', '#8'), P-value: 0.1372, CI Group1: [1.85796641 1.89527061], CI Group2: [1.83581827 1.87538154], Cohen's d: 0.015610492873317115
# Category: Functionality, Pair: ('#6', '#9'), P-value: 0.0002, CI Group1: [1.857866   1.89552164], CI Group2: [2.15699296 2.19903966], Cohen's d: -0.18662958265621393
# Category: Functionality, Pair: ('#7', '#8'), P-value: 0.0002, CI Group1: [1.90978794 1.9480759 ], CI Group2: [1.83511241 1.87544024], Cohen's d: 0.05344063462485511
# Category: Functionality, Pair: ('#7', '#9'), P-value: 0.0002, CI Group1: [1.91017615 1.94836706], CI Group2: [2.15717548 2.19958908], Cohen's d: -0.15285570662460224
# Category: Functionality, Pair: ('#8', '#9'), P-value: 0.0002, CI Group1: [1.83581827 1.87544024], CI Group2: [2.15743231 2.19969915], Cohen's d: -0.1987899181736557
# Category: Strictly Necessary, Pair: ('#1', '#2'), P-value: 0.2498, CI Group1: [1.54553931 1.5873292 ], CI Group2: [1.524576   1.57038007], Cohen's d: 0.009990005758343861
# Category: Strictly Necessary, Pair: ('#1', '#3'), P-value: 0.748, CI Group1: [1.54521402 1.5870755 ], CI Group2: [1.54166667 1.58061531], Cohen's d: 0.0026769051717757827
# Category: Strictly Necessary, Pair: ('#1', '#4'), P-value: 0.2582, CI Group1: [1.54550397 1.58667863], CI Group2: [1.52537072 1.57048331], Cohen's d: 0.010009997776967944
# Category: Strictly Necessary, Pair: ('#1', '#5'), P-value: 0.1714, CI Group1: [1.54579392 1.58682179], CI Group2: [1.52267079 1.56685576], Cohen's d: 0.012308656323635972
# Category: Strictly Necessary, Pair: ('#1', '#6'), P-value: 0.5082, CI Group1: [1.5450328  1.58700482], CI Group2: [1.53475864 1.57594789], Cohen's d: 0.005664414620346213
# Category: Strictly Necessary, Pair: ('#1', '#7'), P-value: 0.6634, CI Group1: [1.54528651 1.58675021], CI Group2: [1.55185905 1.59334093], Cohen's d: -0.003858071506563657
# Category: Strictly Necessary, Pair: ('#1', '#8'), P-value: 0.0216, CI Group1: [1.54532184 1.58722047], CI Group2: [1.50689525 1.55429635], Cohen's d: 0.019446569094615954
# Category: Strictly Necessary, Pair: ('#1', '#9'), P-value: 0.0002, CI Group1: [1.5456127  1.58664057], CI Group2: [1.6145162  1.65264592], Cohen's d: -0.03849348209237038
# Category: Strictly Necessary, Pair: ('#2', '#3'), P-value: 0.3746, CI Group1: [1.52497209 1.57037917], CI Group2: [1.54163183 1.58071897], Cohen's d: -0.007557946496388192
# Category: Strictly Necessary, Pair: ('#2', '#4'), P-value: 0.9886, CI Group1: [1.52518815 1.57066724], CI Group2: [1.52548019 1.57048239], Cohen's d: -3.942000328631442e-05
# Category: Strictly Necessary, Pair: ('#2', '#5'), P-value: 0.8326, CI Group1: [1.52518725 1.56987595], CI Group2: [1.52303198 1.56665466], Cohen's d: 0.001835667860264715
# Category: Strictly Necessary, Pair: ('#2', '#6'), P-value: 0.6034, CI Group1: [1.52508012 1.56976882], CI Group2: [1.53542676 1.57581426], Cohen's d: -0.0044628125593154395
# Category: Strictly Necessary, Pair: ('#2', '#7'), P-value: 0.1076, CI Group1: [1.52504231 1.57027115], CI Group2: [1.55158274 1.59358357], Cohen's d: -0.013517743005213037
# Category: Strictly Necessary, Pair: ('#2', '#8'), P-value: 0.299, CI Group1: [1.52497209 1.56976792], CI Group2: [1.50730972 1.55339299], Cohen's d: 0.009114377036024477
# Category: Strictly Necessary, Pair: ('#2', '#9'), P-value: 0.0002, CI Group1: [1.52464801 1.57016402], CI Group2: [1.61510369 1.65302779], Cohen's d: -0.04689402101775485
# Category: Strictly Necessary, Pair: ('#3', '#4'), P-value: 0.3782, CI Group1: [1.54146275 1.58037656], CI Group2: [1.52500276 1.57019079], Cohen's d: 0.0075631449621098
# Category: Strictly Necessary, Pair: ('#3', '#5'), P-value: 0.2674, CI Group1: [1.54190372 1.58058048], CI Group2: [1.52255173 1.56649458], Cohen's d: 0.009807762206643571
# Category: Strictly Necessary, Pair: ('#3', '#6'), P-value: 0.7174, CI Group1: [1.54163183 1.58078439], CI Group2: [1.53539335 1.57668281], Cohen's d: 0.0030905389500270448
# Category: Strictly Necessary, Pair: ('#3', '#7'), P-value: 0.4428, CI Group1: [1.54153072 1.58129758], CI Group2: [1.55223984 1.59410078], Cohen's d: -0.0065291005819657555
# Category: Strictly Necessary, Pair: ('#3', '#8'), P-value: 0.0378, CI Group1: [1.54136079 1.58044538], CI Group2: [1.50659382 1.55414469], Cohen's d: 0.017151512446817518
# Category: Strictly Necessary, Pair: ('#3', '#9'), P-value: 0.0002, CI Group1: [1.54190457 1.58030944], CI Group2: [1.61478057 1.6524403 ], Cohen's d: -0.041562619199702194
# Category: Strictly Necessary, Pair: ('#4', '#5'), P-value: 0.8454, CI Group1: [1.52533392 1.5695625 ], CI Group2: [1.52283187 1.56697583], Cohen's d: 0.0018878114162788828
# Category: Strictly Necessary, Pair: ('#4', '#6'), P-value: 0.6124, CI Group1: [1.52518674 1.57022482], CI Group2: [1.53556038 1.57611492], Cohen's d: -0.004447230217611205
# Category: Strictly Necessary, Pair: ('#4', '#7'), P-value: 0.1082, CI Group1: [1.52529713 1.5705937 ], CI Group2: [1.55137637 1.59354903], Cohen's d: -0.013552991279292225
# Category: Strictly Necessary, Pair: ('#4', '#8'), P-value: 0.2996, CI Group1: [1.52544431 1.57066637], CI Group2: [1.50648078 1.55373116], Cohen's d: 0.009200326518270985
# Category: Strictly Necessary, Pair: ('#4', '#9'), P-value: 0.0002, CI Group1: [1.52500276 1.57015399], CI Group2: [1.61498693 1.65258864], Cohen's d: -0.04710763094674739
# Category: Strictly Necessary, Pair: ('#5', '#6'), P-value: 0.4602, CI Group1: [1.52235162 1.56637552], CI Group2: [1.53529314 1.57651578], Cohen's d: -0.00652390866442857
# Category: Strictly Necessary, Pair: ('#5', '#7'), P-value: 0.0596, CI Group1: [1.52263077 1.56693681], CI Group2: [1.55147912 1.5942398 ], Cohen's d: -0.015892732887650463
# Category: Strictly Necessary, Pair: ('#5', '#8'), P-value: 0.4338, CI Group1: [1.52243166 1.56685476], CI Group2: [1.50681989 1.55361718], Cohen's d: 0.007594305390226276
# Category: Strictly Necessary, Pair: ('#5', '#9'), P-value: 0.0002, CI Group1: [1.52279185 1.56645556], CI Group2: [1.61475193 1.65261581], Cohen's d: -0.05042496976133567
# Category: Strictly Necessary, Pair: ('#6', '#7'), P-value: 0.2704, CI Group1: [1.53552614 1.57614916], CI Group2: [1.55189445 1.59358357], Cohen's d: -0.009376086094225647
# Category: Strictly Necessary, Pair: ('#6', '#8'), P-value: 0.1, CI Group1: [1.53519292 1.57608235], CI Group2: [1.50659382 1.55335343], Cohen's d: 0.01385272862942617
# Category: Strictly Necessary, Pair: ('#6', '#9'), P-value: 0.0002, CI Group1: [1.53499165 1.57648321], CI Group2: [1.6148687  1.65217592], Cohen's d: -0.043671288705239286
# Category: Strictly Necessary, Pair: ('#7', '#8'), P-value: 0.0048, CI Group1: [1.55196353 1.59406797], CI Group2: [1.50723436 1.55425867], Cohen's d: 0.02279697637598688
# Category: Strictly Necessary, Pair: ('#7', '#9'), P-value: 0.0002, CI Group1: [1.5515836  1.59358357], CI Group2: [1.61480995 1.65261581], Cohen's d: -0.034006410392794215
# Category: Strictly Necessary, Pair: ('#8', '#9'), P-value: 0.0002, CI Group1: [1.50693293 1.55252543], CI Group2: [1.61478131 1.65202905], Cohen's d: -0.05614845334509114

# %% [markdown]
# ### s4_localstorage_vs_profile

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import itertools
from scipy.stats import permutation_test
import os

# Load the data into a DataFrame
path = os.getcwd() + "/datasets-stats/s4_localstorage_vs_profile.csv"
df = pd.read_csv(path)

def bootstrap_ci(data, statistic, alpha):
    """Compute bootstrap confidence interval for given data and statistic."""
    bs_replicates = np.empty(10000)
    
    for i in range(10000):
        bs_sample = np.random.choice(data, len(data))
        bs_replicates[i] = statistic(bs_sample)
        
    return np.percentile(bs_replicates, [100 * alpha / 2., 100 * (1 - alpha / 2.)])

# Define the function for test statistic (difference of means)
def test_statistic(a, b):
    return np.mean(a) - np.mean(b)


# Get unique alias
aliases = df['alias'].unique()

# Generate all pairs of aliases
pairs = list(itertools.combinations(aliases, 2))

# Perform permutation test for each pair
for pair in pairs:
    group1 = df[df['alias'] == pair[0]]['ct'].to_numpy()
    group2 = df[df['alias'] == pair[1]]['ct'].to_numpy()
    
    result = stats.permutation_test((group1, group2), 
                                    test_statistic,
                                    vectorized=False,
                                    alternative='two-sided',
                                    permutation_type='independent')
    
    # Calculate bootstrap confidence intervals for the mean
    ci_group1 = bootstrap_ci(group1, np.mean, 0.05)
    ci_group2 = bootstrap_ci(group2, np.mean, 0.05)
    
    print(f'Pair: {pair}, P-value: {result.pvalue}, CI Group1: {ci_group1}, CI Group2: {ci_group2}')
# Out:
# Pair: (1, 2), P-value: 0.2698, CI Group1: [13.03146222 14.23092769], CI Group2: [12.56046052 13.72401135]
# Pair: (1, 3), P-value: 0.0634, CI Group1: [13.02731523 14.22493937], CI Group2: [13.83077537 15.01735272]
# Pair: (1, 4), P-value: 0.1624, CI Group1: [13.01889201 14.20642073], CI Group2: [12.44833194 13.59890078]
# Pair: (1, 5), P-value: 0.0714, CI Group1: [13.02301187 14.22323047], CI Group2: [12.3019518  13.44683995]
# Pair: (1, 6), P-value: 0.0002, CI Group1: [13.0229656  14.19540624], CI Group2: [10.52595943 11.23825   ]
# Pair: (1, 7), P-value: 0.0456, CI Group1: [13.01728523 14.23553261], CI Group2: [13.89226086 14.844887  ]
# Pair: (1, 8), P-value: 0.0042, CI Group1: [13.02148966 14.22843854], CI Group2: [12.11820261 13.04978267]
# Pair: (1, 9), P-value: 0.0002, CI Group1: [13.01582684 14.22006638], CI Group2: [16.41768113 17.65784121]
# Pair: (2, 3), P-value: 0.0014, CI Group1: [12.57276279 13.71826764], CI Group2: [13.83971702 15.01716021]
# Pair: (2, 4), P-value: 0.7838, CI Group1: [12.549351   13.72862929], CI Group2: [12.44077362 13.57166068]
# Pair: (2, 5), P-value: 0.5166, CI Group1: [12.55325297 13.73601703], CI Group2: [12.3101402  13.41998897]
# Pair: (2, 6), P-value: 0.0002, CI Group1: [12.56155122 13.71795031], CI Group2: [10.52125987 11.24592215]
# Pair: (2, 7), P-value: 0.001, CI Group1: [12.55343953 13.73301442], CI Group2: [13.90339614 14.84725961]
# Pair: (2, 8), P-value: 0.1566, CI Group1: [12.55528766 13.72957807], CI Group2: [12.11981478 13.05988225]
# Pair: (2, 9), P-value: 0.0002, CI Group1: [12.55893131 13.71393194], CI Group2: [16.40133196 17.65702698]
# Pair: (3, 4), P-value: 0.0008, CI Group1: [13.84272053 15.01716334], CI Group2: [12.44192091 13.59186002]
# Pair: (3, 5), P-value: 0.0002, CI Group1: [13.83331246 15.00619796], CI Group2: [12.31114367 13.4448724 ]
# Pair: (3, 6), P-value: 0.0002, CI Group1: [13.83807675 15.02129844], CI Group2: [10.51745285 11.23917105]
# Pair: (3, 7), P-value: 0.9078, CI Group1: [13.82770456 15.00908095], CI Group2: [13.91335608 14.84950545]
# Pair: (3, 8), P-value: 0.0002, CI Group1: [13.83733018 15.00859889], CI Group2: [12.12585636 13.06373427]
# Pair: (3, 9), P-value: 0.0002, CI Group1: [13.82061604 15.01915889], CI Group2: [16.39732993 17.65305568]
# Pair: (4, 5), P-value: 0.7328, CI Group1: [12.43891008 13.60954365], CI Group2: [12.29193447 13.42432892]
# Pair: (4, 6), P-value: 0.0002, CI Group1: [12.44231028 13.60108319], CI Group2: [10.52174342 11.23452522]
# Pair: (4, 7), P-value: 0.0002, CI Group1: [12.43557076 13.60270478], CI Group2: [13.90102197 14.85728841]
# Pair: (4, 8), P-value: 0.28, CI Group1: [12.45262466 13.59704525], CI Group2: [12.11521831 13.05955949]
# Pair: (4, 9), P-value: 0.0002, CI Group1: [12.44680009 13.58079894], CI Group2: [16.40225681 17.66582683]
# Pair: (5, 6), P-value: 0.0002, CI Group1: [12.29407057 13.44373346], CI Group2: [10.52427522 11.24154386]
# Pair: (5, 7), P-value: 0.0002, CI Group1: [12.2973472  13.45293793], CI Group2: [13.90114874 14.83931702]
# Pair: (5, 8), P-value: 0.4842, CI Group1: [12.30143037 13.44323094], CI Group2: [12.13059232 13.04367296]
# Pair: (5, 9), P-value: 0.0002, CI Group1: [12.30886578 13.45277253], CI Group2: [16.40655534 17.67739814]
# Pair: (6, 7), P-value: 0.0002, CI Group1: [10.52662171 11.24811842], CI Group2: [13.90459497 14.83958464]
# Pair: (6, 8), P-value: 0.0002, CI Group1: [10.53030592 11.24089583], CI Group2: [12.1180615  13.05229337]
# Pair: (6, 9), P-value: 0.0002, CI Group1: [10.52244408 11.23936732], CI Group2: [16.41331193 17.65786272]
# Pair: (7, 8), P-value: 0.0002, CI Group1: [13.89989671 14.84174753], CI Group2: [12.11385591 13.04497859]
# Pair: (7, 9), P-value: 0.0002, CI Group1: [13.8961406  14.83969263], CI Group2: [16.42302894 17.68194248]
# Pair: (8, 9), P-value: 0.0002, CI Group1: [12.12274393 13.05477164], CI Group2: [16.42004855 17.66282646]

# %% [markdown]
# ### s5_tracking_vs_profile

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import itertools
from scipy.stats import permutation_test
import os

# Load the data into a DataFrame
path = os.getcwd() + "/datasets-stats/s5_tracking_vs_profile.csv"
df = pd.read_csv(path)

def bootstrap_ci(data, statistic, alpha):
    """Compute bootstrap confidence interval for given data and statistic."""
    bs_replicates = np.empty(10000)
    
    for i in range(10000):
        bs_sample = np.random.choice(data, len(data))
        bs_replicates[i] = statistic(bs_sample)
        
    return np.percentile(bs_replicates, [100 * alpha / 2., 100 * (1 - alpha / 2.)])

# Define the function for test statistic (difference of means)
def test_statistic(a, b):
    return np.mean(a) - np.mean(b)


# Get unique alias
aliases = df['alias'].unique()

# Generate all pairs of aliases
pairs = list(itertools.combinations(aliases, 2))

# Perform permutation test for each pair
for pair in pairs:
    group1 = df[df['alias'] == pair[0]]['ct'].to_numpy()
    group2 = df[df['alias'] == pair[1]]['ct'].to_numpy()
    
    result = stats.permutation_test((group1, group2), 
                                    test_statistic,
                                    vectorized=False,
                                    alternative='two-sided',
                                    permutation_type='independent')
    
    # Calculate bootstrap confidence intervals for the mean
    ci_group1 = bootstrap_ci(group1, np.mean, 0.05)
    ci_group2 = bootstrap_ci(group2, np.mean, 0.05)
    
    print(f'Pair: {pair}, P-value: {result.pvalue}, CI Group1: {ci_group1}, CI Group2: {ci_group2}')
# Out:
# Pair: (1, 2), P-value: 0.0002, CI Group1: [98.07855821 99.20995079], CI Group2: [93.57843429 94.59432868]
# Pair: (1, 3), P-value: 0.0002, CI Group1: [98.0882461  99.22067603], CI Group2: [103.08507869 104.21367739]
# Pair: (1, 4), P-value: 0.0002, CI Group1: [98.093106   99.22433404], CI Group2: [94.88100429 95.91054308]
# Pair: (1, 5), P-value: 0.0002, CI Group1: [98.08327641 99.21366965], CI Group2: [96.51792276 97.56923934]
# Pair: (1, 6), P-value: 0.0002, CI Group1: [98.08941439 99.21222146], CI Group2: [100.83773582 101.9208071 ]
# Pair: (1, 7), P-value: 0.0002, CI Group1: [98.09448919 99.21423985], CI Group2: [105.54101899 106.75193262]
# Pair: (1, 8), P-value: 0.0002, CI Group1: [98.08505461 99.21570778], CI Group2: [92.63612413 93.70397991]
# Pair: (1, 9), P-value: 0.0002, CI Group1: [98.0880957 99.2181461], CI Group2: [115.17785425 116.61186481]
# Pair: (2, 3), P-value: 0.0002, CI Group1: [93.58995184 94.58363238], CI Group2: [103.0842562  104.20386602]
# Pair: (2, 4), P-value: 0.0006, CI Group1: [93.59046659 94.59750826], CI Group2: [94.87510781 95.89585979]
# Pair: (2, 5), P-value: 0.0002, CI Group1: [93.58047154 94.58504321], CI Group2: [96.54997275 97.56856252]
# Pair: (2, 6), P-value: 0.0002, CI Group1: [93.58940326 94.5817953 ], CI Group2: [100.83011654 101.90901764]
# Pair: (2, 7), P-value: 0.0002, CI Group1: [93.5855249  94.59470091], CI Group2: [105.55066609 106.77185572]
# Pair: (2, 8), P-value: 0.0154, CI Group1: [93.58774267 94.59177174], CI Group2: [92.64143159 93.68791787]
# Pair: (2, 9), P-value: 0.0002, CI Group1: [93.60302613 94.59974569], CI Group2: [115.17410064 116.62485659]
# Pair: (3, 4), P-value: 0.0002, CI Group1: [103.09052359 104.22324002], CI Group2: [94.86016251 95.91126663]
# Pair: (3, 5), P-value: 0.0002, CI Group1: [103.08870656 104.22373555], CI Group2: [96.55435495 97.56667218]
# Pair: (3, 6), P-value: 0.0002, CI Group1: [103.07547049 104.21775239], CI Group2: [100.83388593 101.90410073]
# Pair: (3, 7), P-value: 0.0002, CI Group1: [103.08480904 104.22742138], CI Group2: [105.56150925 106.75072772]
# Pair: (3, 8), P-value: 0.0002, CI Group1: [103.07107847 104.23160235], CI Group2: [92.64414332 93.69163153]
# Pair: (3, 9), P-value: 0.0002, CI Group1: [103.09472083 104.22991091], CI Group2: [115.18279627 116.61157877]
# Pair: (4, 5), P-value: 0.0004, CI Group1: [94.87163051 95.91354211], CI Group2: [96.5510164 97.5793968]
# Pair: (4, 6), P-value: 0.0002, CI Group1: [94.87030935 95.89932439], CI Group2: [100.82553672 101.90761646]
# Pair: (4, 7), P-value: 0.0002, CI Group1: [94.88637457 95.91633072], CI Group2: [105.54970277 106.74261889]
# Pair: (4, 8), P-value: 0.0002, CI Group1: [94.87608326 95.88843275], CI Group2: [92.6355651 93.7149547]
# Pair: (4, 9), P-value: 0.0002, CI Group1: [94.88247187 95.92484658], CI Group2: [115.17055497 116.60119243]
# Pair: (5, 6), P-value: 0.0002, CI Group1: [96.5404628  97.56994756], CI Group2: [100.84183128 101.90246385]
# Pair: (5, 7), P-value: 0.0002, CI Group1: [96.53113498 97.57481878], CI Group2: [105.5574062  106.76107212]
# Pair: (5, 8), P-value: 0.0002, CI Group1: [96.53632214 97.58175433], CI Group2: [92.65007807 93.69738478]
# Pair: (5, 9), P-value: 0.0002, CI Group1: [96.53917153 97.56069284], CI Group2: [115.18145926 116.60156865]
# Pair: (6, 7), P-value: 0.0002, CI Group1: [100.82853422 101.89786902], CI Group2: [105.5585509  106.75521576]
# Pair: (6, 8), P-value: 0.0002, CI Group1: [100.81875751 101.91077211], CI Group2: [92.64048078 93.69170803]
# Pair: (6, 9), P-value: 0.0002, CI Group1: [100.82750557 101.90024429], CI Group2: [115.17444797 116.61161053]
# Pair: (7, 8), P-value: 0.0002, CI Group1: [105.54694349 106.7680516 ], CI Group2: [92.64215983 93.70218552]
# Pair: (7, 9), P-value: 0.0002, CI Group1: [105.55116875 106.76143058], CI Group2: [115.17224751 116.62416453]
# Pair: (8, 9), P-value: 0.0002, CI Group1: [92.63549775 93.70093983], CI Group2: [115.19076353 116.61990092]

# %% [markdown]
# ### s6_first_third_rejectall

# %%
import numpy as np
import pandas as pd
from scipy import stats
import itertools
from scipy.stats import permutation_test

# Assuming df is your DataFrame
path = os.getcwd() + "/datasets-stats/s2_1s-3rd_vs_profile.csv"

df=pd.read_csv(path)
df = df.dropna(subset=['is_third_party'])

df = df[df['alias'].isin([2, 4])]

# Create a new column combining 'alias' and 'is_third_party'
df['alias_third_party'] = df['alias'].astype(str) + '_' + df['is_third_party'].astype(str)

# Get unique alias_third_party
aliases_third_party = df['alias_third_party'].unique()

# Generate all pairs of alias_third_party
pairs = list(itertools.combinations(aliases_third_party, 2))

# Define the function for test statistic (difference of means)
def test_statistic(a, b):
    return np.mean(a) - np.mean(b)


def bootstrap_ci(data, statistic, alpha):
    """Compute bootstrap confidence interval for given data and statistic."""
    bs_replicates = np.empty(10000)
    
    for i in range(10000):
        bs_sample = np.random.choice(data, len(data))
        bs_replicates[i] = statistic(bs_sample)
        
    return np.percentile(bs_replicates, [100 * alpha / 2., 100 * (1 - alpha / 2.)])

# Perform permutation test for each pair
for pair in pairs:
    group1 = df[df['alias_third_party'] == pair[0]]['ct'].to_numpy()
    group2 = df[df['alias_third_party'] == pair[1]]['ct'].to_numpy()

    result = stats.permutation_test((group1, group2), test_statistic, 
                                    vectorized=False, alternative='two-sided',
                                    permutation_type='independent')
    

    # Calculate bootstrap confidence intervals for the mean
    ci_group1 = bootstrap_ci(group1, np.mean, 0.05)
    ci_group2 = bootstrap_ci(group2, np.mean, 0.05)
    print(f'Pair: {pair}, P-value: {result.pvalue}, CI Group1: {ci_group1}, CI Group2: {ci_group2}')
 

print("Only check 2_1.0, 4_1.0 and 2_0.0, 4_0.0")
# Out:
# Pair: ('2_1.0', '2_0.0'), P-value: 0.0002, CI Group1: [21.09339213 22.1903351 ], CI Group2: [13.92110341 14.33900115]
# Pair: ('2_1.0', '4_0.0'), P-value: 0.0002, CI Group1: [21.11400069 22.18120255], CI Group2: [13.80806452 14.22653616]
# Pair: ('2_1.0', '4_1.0'), P-value: 0.8946, CI Group1: [21.10609979 22.16704773], CI Group2: [21.06451839 22.13605747]
# Pair: ('2_0.0', '4_0.0'), P-value: 0.4386, CI Group1: [13.92198858 14.34364603], CI Group2: [13.79921436 14.22476847]
# Pair: ('2_0.0', '4_1.0'), P-value: 0.0002, CI Group1: [13.9152005  14.34573317], CI Group2: [21.06434649 22.10894453]
# Pair: ('4_0.0', '4_1.0'), P-value: 0.0002, CI Group1: [13.79546956 14.22955385], CI Group2: [21.06732609 22.12710864]
# Only check 2_1.0, 4_1.0 and 2_0.0, 4_0.0

# %% [markdown]
# ### s7_localstorage_vs_profile

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import itertools
from scipy.stats import permutation_test
import os

def bootstrap_ci(data, statistic, alpha):
    """Compute bootstrap confidence interval for given data and statistic."""
    bs_replicates = np.empty(10000)
    
    for i in range(10000):
        bs_sample = np.random.choice(data, len(data))
        bs_replicates[i] = statistic(bs_sample)
        
    return np.percentile(bs_replicates, [100 * alpha / 2., 100 * (1 - alpha / 2.)])

# Define the function for test statistic (difference of means)
def test_statistic(a, b):
    return np.mean(a) - np.mean(b)

# Load the data into a DataFrame
path = os.getcwd() + "/datasets-stats/s1_cookies_vs_profile.csv"
df = pd.read_csv(path)
df = df[df['alias'].isin(["#3", "#7","#8"])]


# Get unique alias
aliases = df['alias'].unique()

# Generate all pairs of aliases
pairs = list(itertools.combinations(aliases, 2))

# Perform permutation test for each pair
for pair in pairs:
    group1 = df[df['alias'] == pair[0]]['ct'].to_numpy()
    group2 = df[df['alias'] == pair[1]]['ct'].to_numpy()
    
    result = stats.permutation_test((group1, group2), 
                                    test_statistic,
                                    vectorized=False,
                                    alternative='two-sided',
                                    permutation_type='independent')
    
    # Calculate bootstrap confidence intervals for the mean
    ci_group1 = bootstrap_ci(group1, np.mean, 0.05)
    ci_group2 = bootstrap_ci(group2, np.mean, 0.05)
    
    print(f'Pair: {pair}, P-value: {result.pvalue}, CI Group1: {ci_group1}, CI Group2: {ci_group2}')
# Out:
# Pair: ('#3', '#7'), P-value: 0.0002, CI Group1: [35.26030627 36.56885125], CI Group2: [37.92220219 39.44034554]
# Pair: ('#3', '#8'), P-value: 0.0002, CI Group1: [35.25093375 36.56601149], CI Group2: [30.17406807 31.26127439]
# Pair: ('#7', '#8'), P-value: 0.0002, CI Group1: [37.9114682  39.41743742], CI Group2: [30.16776596 31.26246092]

# %% [markdown]
# ## s8_cat_ls_vs_profile

# %%
import pandas as pd
from scipy.stats import f_oneway
import os

path = os.getcwd() + "/datasets-stats/s8_cat_ls_vs_profile.csv"

df_main = pd.read_csv(path)

#Unknown
df = df_main[df_main['category']=='Unknown']  
uniq = pd.unique(df['alias'])
params=[]
for item in uniq:
    params.append(df[df['alias']==item]['ct'])
cat_unknown=f_oneway(*params)

#Targeting/Advertising
df = df_main[df_main['category']=='Targeting/Advertising']
uniq = pd.unique(df['alias'])
params=[]
for item in uniq:
    params.append(df[df['alias']==item]['ct'])
cat_targeting=f_oneway(*params)

#Performance
df = df_main[df_main['category']=='Performance']
uniq = pd.unique(df['alias'])
params=[]
for item in uniq:
    params.append(df[df['alias']==item]['ct'])
cat_perf=f_oneway(*params)

#Strictly Necessary
df = df_main[df_main['category']=='Strictly Necessary']
uniq = pd.unique(df['alias'])
params=[]
for item in uniq:
    params.append(df[df['alias']==item]['ct'])
cat_strict=f_oneway(*params)
    

#Functionality
df = df_main[df_main['category']=='Functionality']
uniq = pd.unique(df['alias'])
params=[]
for item in uniq:
    params.append(df[df['alias']==item]['ct'])
cat_func=f_oneway(*params)
 


results={}
results['Unknown']=cat_unknown
results['Targeting/Advertising']=cat_targeting
results['Performance']=cat_perf
results['Strictly Necessary']=cat_strict
results['Functionality']=cat_func

results
# Out:
# {'Unknown': F_onewayResult(statistic=31.42085716122143, pvalue=1.046346986816549e-49),
#  'Targeting/Advertising': F_onewayResult(statistic=1.0384622078210886, pvalue=0.40404808318790303),
#  'Performance': F_onewayResult(statistic=0.27352215880199654, pvalue=0.9746808839711721),
#  'Strictly Necessary': F_onewayResult(statistic=0.4772166318223201, pvalue=0.8729543784168162),
#  'Functionality': F_onewayResult(statistic=0.21258864895974963, pvalue=0.9888430159660452)}

# %% [markdown]
# ### s9_tracking_vs_profile

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import itertools
from scipy.stats import permutation_test
import os

def bootstrap_ci(data, statistic, alpha):
    """Compute bootstrap confidence interval for given data and statistic."""
    bs_replicates = np.empty(10000)
    
    for i in range(10000):
        bs_sample = np.random.choice(data, len(data))
        bs_replicates[i] = statistic(bs_sample)
        
    return np.percentile(bs_replicates, [100 * alpha / 2., 100 * (1 - alpha / 2.)])

# Define the function for test statistic (difference of means)
def test_statistic(a, b):
    return np.mean(a) - np.mean(b)

# Load the data into a DataFrame
path = os.getcwd() + "/datasets-stats/s9_tracking_vs_profile.csv"
df = pd.read_csv(path)

# Get unique alias
aliases = df['alias'].unique()

# Generate all pairs of aliases
pairs = list(itertools.combinations(aliases, 2))

# Perform permutation test for each pair
for pair in pairs:
    group1 = df[df['alias'] == pair[0]]['ct'].to_numpy()
    group2 = df[df['alias'] == pair[1]]['ct'].to_numpy()
    
    result = stats.permutation_test((group1, group2), 
                                    test_statistic,
                                    vectorized=False,
                                    alternative='two-sided',
                                    permutation_type='independent')
    
    # Calculate bootstrap confidence intervals for the mean
    ci_group1 = bootstrap_ci(group1, np.mean, 0.05)
    ci_group2 = bootstrap_ci(group2, np.mean, 0.05)
    
    print(f'Pair: {pair}, P-value: {result.pvalue}, CI Group1: {ci_group1}, CI Group2: {ci_group2}')
# Out:
# Pair: ('#1', '#2'), P-value: 0.0002, CI Group1: [15.77923734 16.31666303], CI Group2: [15.25115028 15.49554881]
# Pair: ('#1', '#3'), P-value: 0.0002, CI Group1: [15.78392989 16.29813855], CI Group2: [16.61155359 17.03643985]
# Pair: ('#1', '#4'), P-value: 0.0002, CI Group1: [15.78527324 16.31055756], CI Group2: [15.29085255 15.69761532]
# Pair: ('#1', '#5'), P-value: 0.0002, CI Group1: [15.78355537 16.30816792], CI Group2: [16.68629503 16.95946818]
# Pair: ('#1', '#6'), P-value: 0.9542, CI Group1: [15.78160798 16.315259  ], CI Group2: [15.85766051 16.10395206]
# Pair: ('#1', '#7'), P-value: 0.0002, CI Group1: [15.78214104 16.3032774 ], CI Group2: [17.11617174 17.39227744]
# Pair: ('#1', '#8'), P-value: 0.0078, CI Group1: [15.78182618 16.30686763], CI Group2: [15.28052549 15.90071925]
# Pair: ('#1', '#9'), P-value: 0.0002, CI Group1: [15.78678525 16.30757642], CI Group2: [20.31540689 20.65704671]
# Pair: ('#2', '#3'), P-value: 0.0002, CI Group1: [15.25222336 15.4945765 ], CI Group2: [16.60898633 17.03158458]
# Pair: ('#2', '#4'), P-value: 0.4616, CI Group1: [15.25201675 15.49519653], CI Group2: [15.28964589 15.69660611]
# Pair: ('#2', '#5'), P-value: 0.0002, CI Group1: [15.25005384 15.49429228], CI Group2: [16.68520899 16.95799603]
# Pair: ('#2', '#6'), P-value: 0.0002, CI Group1: [15.25050769 15.49625803], CI Group2: [15.86083473 16.10380367]
# Pair: ('#2', '#7'), P-value: 0.0002, CI Group1: [15.25150906 15.49489363], CI Group2: [17.114875   17.38764582]
# Pair: ('#2', '#8'), P-value: 0.4418, CI Group1: [15.25224672 15.49595188], CI Group2: [15.284298   15.89295223]
# Pair: ('#2', '#9'), P-value: 0.0002, CI Group1: [15.25179998 15.49487676], CI Group2: [20.3178677 20.6516492]
# Pair: ('#3', '#4'), P-value: 0.0002, CI Group1: [16.6107606  17.03707972], CI Group2: [15.29095359 15.6893589 ]
# Pair: ('#3', '#5'), P-value: 0.872, CI Group1: [16.61103966 17.04088974], CI Group2: [16.68752326 16.95693779]
# Pair: ('#3', '#6'), P-value: 0.0002, CI Group1: [16.60879882 17.03764722], CI Group2: [15.86029971 16.10212064]
# Pair: ('#3', '#7'), P-value: 0.0002, CI Group1: [16.61516351 17.03748451], CI Group2: [17.11597192 17.38896792]
# Pair: ('#3', '#8'), P-value: 0.0002, CI Group1: [16.61104706 17.03897173], CI Group2: [15.28122187 15.89102662]
# Pair: ('#3', '#9'), P-value: 0.0002, CI Group1: [16.61482149 17.04797006], CI Group2: [20.31437718 20.65129918]
# Pair: ('#4', '#5'), P-value: 0.0002, CI Group1: [15.29187305 15.69919186], CI Group2: [16.68643018 16.959954  ]
# Pair: ('#4', '#6'), P-value: 0.0002, CI Group1: [15.28791163 15.69404234], CI Group2: [15.86166612 16.10312423]
# Pair: ('#4', '#7'), P-value: 0.0002, CI Group1: [15.29417908 15.70215012], CI Group2: [17.11430268 17.39209878]
# Pair: ('#4', '#8'), P-value: 0.786, CI Group1: [15.29149369 15.69912854], CI Group2: [15.27730224 15.8970538 ]
# Pair: ('#4', '#9'), P-value: 0.0002, CI Group1: [15.29219131 15.69710305], CI Group2: [20.31389766 20.65207776]
# Pair: ('#5', '#6'), P-value: 0.0002, CI Group1: [16.68967258 16.95771304], CI Group2: [15.86145922 16.10364041]
# Pair: ('#5', '#7'), P-value: 0.0002, CI Group1: [16.68908464 16.95960212], CI Group2: [17.1170894  17.39357179]
# Pair: ('#5', '#8'), P-value: 0.0002, CI Group1: [16.68554556 16.95527812], CI Group2: [15.28010232 15.89187478]
# Pair: ('#5', '#9'), P-value: 0.0002, CI Group1: [16.68885845 16.95973707], CI Group2: [20.31274872 20.65358216]
# Pair: ('#6', '#7'), P-value: 0.0002, CI Group1: [15.86177047 16.10139498], CI Group2: [17.11656819 17.3917704 ]
# Pair: ('#6', '#8'), P-value: 0.0002, CI Group1: [15.85938777 16.10257017], CI Group2: [15.27965851 15.89714649]
# Pair: ('#6', '#9'), P-value: 0.0002, CI Group1: [15.85966034 16.10102957], CI Group2: [20.31752171 20.65147963]
# Pair: ('#7', '#8'), P-value: 0.0002, CI Group1: [17.11555032 17.3873398 ], CI Group2: [15.28144853 15.89797927]
# Pair: ('#7', '#9'), P-value: 0.0002, CI Group1: [17.1164574  17.39001154], CI Group2: [20.31952778 20.65320636]
# Pair: ('#8', '#9'), P-value: 0.0002, CI Group1: [15.28578708 15.89965394], CI Group2: [20.3186928  20.65247048]

# %% [markdown]
# ## s10 multiple runs

# %%
import pandas as pd
from skbio.stats.distance import permanova
from skbio import DistanceMatrix
from sklearn.metrics.pairwise import euclidean_distances
import os 

# Load the data
path = os.getcwd() + "/datasets-stats/s10_multiple_runs_scope.zip"
df = pd.read_csv(path)


# Create a pivot table with sum of ct for each combination of measurement_id, browser_id, and category
pivot_table = pd.pivot_table(df, values='ct', index=['measurement_id', 'browser_id'], columns=['category'], aggfunc='sum', fill_value=0)

# Calculate Euclidean distance matrix
distance_matrix = euclidean_distances(pivot_table.values)
distance_matrix = DistanceMatrix(distance_matrix)

# Prepare the grouping variable (measurement_id)
grouping = pivot_table.index.get_level_values('measurement_id')

# Perform PERMANOVA
result = permanova(distance_matrix, grouping, permutations=9999)

print(result)
# Out:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      27
# number of groups                  3
# test statistic             0.210757
# p-value                      0.8713
# number of permutations         9999
# Name: PERMANOVA results, dtype: object

# %% [markdown]
# ### s11: o matic all configurations

# %%
import pandas as pd
import os
import scipy.stats as stats
import numpy as np
import scikit_posthocs as sp

# Load the data
df = pd.read_csv(os.getcwd() + '/datasets-plots/p11_stats_omatic_all_settings.zip')

# Initialize a dictionary to store results
results = {}

# Perform Kruskal-Wallis test for each category, and if significant, perform Dunn's test
for category in df['category'].unique():
    data = {browser: df.loc[(df['category'] == category) & (df['browser_id'] == browser), 'ct'].values for browser in df['browser_id'].unique()}
    h_statistic, p_value = stats.kruskal(*data.values())
    if p_value < 0.05:
        posthoc = sp.posthoc_dunn(df[df['category'] == category], val_col='ct', group_col='browser_id', p_adjust = 'holm')
        results[category] = posthoc

# Print results and mark the significant differences with "✓" and non-significant with "✖"
for category, result in results.items():
    print("Category:", category)
    result = result.applymap(lambda x: round(x,2) if x < 0.05 else round(x,2))
    print(result)
    print('\n')
# Out:
# Category: Tracking requests
#                  openwpm_nothing  openwpm_omatic  openwpm_omaticA
# openwpm_nothing              1.0            0.00             0.00  \
# openwpm_omatic               0.0            1.00             0.03
# openwpm_omaticA              0.0            0.03             1.00
# openwpm_omaticB              0.0            0.00             0.39
# openwpm_omaticC              0.0            1.00             0.12
# openwpm_omaticD              0.0            0.09             1.00
# openwpm_omaticE              0.0            0.00             0.08
# openwpm_omaticF              0.0            1.00             0.26
#
#                  openwpm_omaticB  openwpm_omaticC  openwpm_omaticD
# openwpm_nothing             0.00             0.00             0.00  \
# openwpm_omatic              0.00             1.00             0.09
# openwpm_omaticA             0.39             0.12             1.00
# openwpm_omaticB             1.00             0.00             0.19
# openwpm_omaticC             0.00             1.00             0.27
# openwpm_omaticD             0.19             0.27             1.00
# openwpm_omaticE             1.00             0.00             0.02
# openwpm_omaticF             0.00             1.00             0.47
#
#                  openwpm_omaticE  openwpm_omaticF
# openwpm_nothing             0.00             0.00
# openwpm_omatic              0.00             1.00
# openwpm_omaticA             0.08             0.26
# openwpm_omaticB             1.00             0.00
# openwpm_omaticC             0.00             1.00
# openwpm_omaticD             0.02             0.47
# openwpm_omaticE             1.00             0.00
# openwpm_omaticF             0.00             1.00
#
#
# Category: Unknown
#                  openwpm_nothing  openwpm_omatic  openwpm_omaticA
# openwpm_nothing              1.0            0.00             0.00  \
# openwpm_omatic               0.0            1.00             0.01
# openwpm_omaticA              0.0            0.01             1.00
# openwpm_omaticB              0.0            0.00             0.97
# openwpm_omaticC              0.0            1.00             0.01
# openwpm_omaticD              0.0            0.67             0.67
# openwpm_omaticE              0.0            0.00             0.22
# openwpm_omaticF              0.0            0.58             0.67
#
#                  openwpm_omaticB  openwpm_omaticC  openwpm_omaticD
# openwpm_nothing             0.00             0.00             0.00  \
# openwpm_omatic              0.00             1.00             0.67
# openwpm_omaticA             0.97             0.01             0.67
# openwpm_omaticB             1.00             0.00             0.05
# openwpm_omaticC             0.00             1.00             0.67
# openwpm_omaticD             0.05             0.67             1.00
# openwpm_omaticE             0.97             0.00             0.00
# openwpm_omaticF             0.06             0.67             1.00
#
#                  openwpm_omaticE  openwpm_omaticF
# openwpm_nothing             0.00             0.00
# openwpm_omatic              0.00             0.58
# openwpm_omaticA             0.22             0.67
# openwpm_omaticB             0.97             0.06
# openwpm_omaticC             0.00             0.67
# openwpm_omaticD             0.00             1.00
# openwpm_omaticE             1.00             0.00
# openwpm_omaticF             0.00             1.00
#
#
# Category: Performance
#                  openwpm_nothing  openwpm_omatic  openwpm_omaticA
# openwpm_nothing             1.00            0.03             0.00  \
# openwpm_omatic              0.03            1.00             0.59
# openwpm_omaticA             0.00            0.59             1.00
# openwpm_omaticB             0.00            0.00             0.00
# openwpm_omaticC             1.00            0.00             0.00
# openwpm_omaticD             0.02            1.00             0.59
# openwpm_omaticE             0.12            0.00             0.00
# openwpm_omaticF             1.00            0.08             0.00
#
#                  openwpm_omaticB  openwpm_omaticC  openwpm_omaticD
# openwpm_nothing              0.0             1.00             0.02  \
# openwpm_omatic               0.0             0.00             1.00
# openwpm_omaticA              0.0             0.00             0.59
# openwpm_omaticB              1.0             0.00             0.00
# openwpm_omaticC              0.0             1.00             0.00
# openwpm_omaticD              0.0             0.00             1.00
# openwpm_omaticE              0.0             0.59             0.00
# openwpm_omaticF              0.0             1.00             0.06
#
#                  openwpm_omaticE  openwpm_omaticF
# openwpm_nothing             0.12             1.00
# openwpm_omatic              0.00             0.08
# openwpm_omaticA             0.00             0.00
# openwpm_omaticB             0.00             0.00
# openwpm_omaticC             0.59             1.00
# openwpm_omaticD             0.00             0.06
# openwpm_omaticE             1.00             0.05
# openwpm_omaticF             0.05             1.00
#
#
# Category: Targeting/Advertising
#                  openwpm_nothing  openwpm_omatic  openwpm_omaticA
# openwpm_nothing             1.00            0.00             0.00  \
# openwpm_omatic              0.00            1.00             1.00
# openwpm_omaticA             0.00            1.00             1.00
# openwpm_omaticB             0.00            0.14             0.02
# openwpm_omaticC             0.00            0.04             0.00
# openwpm_omaticD             0.65            0.04             0.22
# openwpm_omaticE             0.00            0.00             0.00
# openwpm_omaticF             0.00            1.00             0.65
#
#                  openwpm_omaticB  openwpm_omaticC  openwpm_omaticD
# openwpm_nothing             0.00             0.00             0.65  \
# openwpm_omatic              0.14             0.04             0.04
# openwpm_omaticA             0.02             0.00             0.22
# openwpm_omaticB             1.00             1.00             0.00
# openwpm_omaticC             1.00             1.00             0.00
# openwpm_omaticD             0.00             0.00             1.00
# openwpm_omaticE             0.00             0.00             0.00
# openwpm_omaticF             0.65             0.29             0.00
#
#                  openwpm_omaticE  openwpm_omaticF
# openwpm_nothing              0.0             0.00
# openwpm_omatic               0.0             1.00
# openwpm_omaticA              0.0             0.65
# openwpm_omaticB              0.0             0.65
# openwpm_omaticC              0.0             0.29
# openwpm_omaticD              0.0             0.00
# openwpm_omaticE              1.0             0.00
# openwpm_omaticF              0.0             1.00
#
#
# Category: Strictly Necessary
#                  openwpm_nothing  openwpm_omatic  openwpm_omaticA
# openwpm_nothing             1.00            0.11             0.00  \
# openwpm_omatic              0.11            1.00             0.90
# openwpm_omaticA             0.00            0.90             1.00
# openwpm_omaticB             0.00            0.00             0.26
# openwpm_omaticC             0.02            1.00             1.00
# openwpm_omaticD             0.00            1.00             1.00
# openwpm_omaticE             0.00            0.35             1.00
# openwpm_omaticF             0.00            0.78             1.00
#
#                  openwpm_omaticB  openwpm_omaticC  openwpm_omaticD
# openwpm_nothing             0.00             0.02             0.00  \
# openwpm_omatic              0.00             1.00             1.00
# openwpm_omaticA             0.26             1.00             1.00
# openwpm_omaticB             1.00             0.01             0.04
# openwpm_omaticC             0.01             1.00             1.00
# openwpm_omaticD             0.04             1.00             1.00
# openwpm_omaticE             0.76             1.00             1.00
# openwpm_omaticF             0.32             1.00             1.00
#
#                  openwpm_omaticE  openwpm_omaticF
# openwpm_nothing             0.00             0.00
# openwpm_omatic              0.35             0.78
# openwpm_omaticA             1.00             1.00
# openwpm_omaticB             0.76             0.32
# openwpm_omaticC             1.00             1.00
# openwpm_omaticD             1.00             1.00
# openwpm_omaticE             1.00             1.00
# openwpm_omaticF             1.00             1.00
#
#
# Category: Functionality
#                  openwpm_nothing  openwpm_omatic  openwpm_omaticA
# openwpm_nothing             1.00            1.00             0.06  \
# openwpm_omatic              1.00            1.00             0.02
# openwpm_omaticA             0.06            0.02             1.00
# openwpm_omaticB             0.00            0.00             1.00
# openwpm_omaticC             1.00            1.00             0.04
# openwpm_omaticD             1.00            1.00             0.46
# openwpm_omaticE             1.00            1.00             0.00
# openwpm_omaticF             1.00            1.00             0.01
#
#                  openwpm_omaticB  openwpm_omaticC  openwpm_omaticD
# openwpm_nothing             0.00             1.00             1.00  \
# openwpm_omatic              0.00             1.00             1.00
# openwpm_omaticA             1.00             0.04             0.46
# openwpm_omaticB             1.00             0.00             0.05
# openwpm_omaticC             0.00             1.00             1.00
# openwpm_omaticD             0.05             1.00             1.00
# openwpm_omaticE             0.00             1.00             1.00
# openwpm_omaticF             0.00             1.00             1.00
#
#                  openwpm_omaticE  openwpm_omaticF
# openwpm_nothing              1.0             1.00
# openwpm_omatic               1.0             1.00
# openwpm_omaticA              0.0             0.01
# openwpm_omaticB              0.0             0.00
# openwpm_omaticC              1.0             1.00
# openwpm_omaticD              1.0             1.00
# openwpm_omaticE              1.0             1.00
# openwpm_omaticF              1.0             1.00

# %%
## Here we calculate kruskal +  η2

import pandas as pd
from scipy.stats import kruskal
import os

path = os.getcwd() + "/datasets-stats/s10_multiple_runs_scope.zip"
df = pd.read_csv(path)

# Replace spaces with underscore in the 'category' column
df['category'] = df['category'].str.replace(' ', '_')

# Create a new column 'browser_category'
df['browser_category'] = df['category'] + "_" + df['browser_id']

# Get the unique browser_categories
browser_categories = df['browser_category'].unique()

# Get the unique measurement_ids
measurement_ids = df['measurement_id'].unique()

results = []

# Perform Kruskal-Wallis test for each browser_category across different measurement_id
for browser_category in browser_categories:
    data = [df[(df['browser_category'] == browser_category) & (df['measurement_id'] == measurement_id)]['ct']
            for measurement_id in measurement_ids]
    H, pval = kruskal(*data)
    # calculate eta squared
    n = sum([len(d) for d in data])
    eta_squared = H / (n - 1)
    results.append((browser_category, H, round(pval,2), eta_squared))

# Convert the results into a DataFrame
results_df = pd.DataFrame(results, columns=['browser_category', 'H-statistic', 'p-value', 'eta-squared'])

print(results_df)
# Out:
#             browser_category  H-statistic  p-value  eta-squared
# 0       Tracking_requests_#1    13.724815     0.00     0.000142
# 1             Performance_#1    36.286949     0.00     0.000490
# 2                 Unknown_#1     5.520514     0.06     0.000067
# 3      Strictly_Necessary_#1    10.048000     0.01     0.000223
# 4   Targeting/Advertising_#1     1.924505     0.38     0.000035
# 5           Functionality_#1     6.378924     0.04     0.000208
# 6       Tracking_requests_#2     4.237398     0.12     0.000043
# 7                 Unknown_#2     3.499560     0.17     0.000042
# 8             Performance_#2    27.969458     0.00     0.000393
# 9   Targeting/Advertising_#2     6.926378     0.03     0.000135
# 10     Strictly_Necessary_#2     6.777803     0.03     0.000145
# 11          Functionality_#2     1.598093     0.45     0.000053
# 12      Tracking_requests_#3    13.862557     0.00     0.000142
# 13                Unknown_#3    25.808631     0.00     0.000306
# 14     Strictly_Necessary_#3     9.529359     0.01     0.000203
# 15  Targeting/Advertising_#3    34.108119     0.00     0.000594
# 16            Performance_#3    46.719151     0.00     0.000611
# 17          Functionality_#3     6.485196     0.04     0.000187
# 18      Tracking_requests_#4    15.134936     0.00     0.000157
# 19  Targeting/Advertising_#4     0.955513     0.62     0.000019
# 20            Performance_#4    54.202282     0.00     0.000765
# 21                Unknown_#4     9.032733     0.01     0.000110
# 22     Strictly_Necessary_#4    15.795714     0.00     0.000346
# 23          Functionality_#4     5.931923     0.05     0.000199
# 24      Tracking_requests_#5    31.148222     0.00     0.000327
# 25            Performance_#5    92.621699     0.00     0.001311
# 26                Unknown_#5    31.247492     0.00     0.000373
# 27     Strictly_Necessary_#5    44.440964     0.00     0.000932
# 28          Functionality_#5     3.855041     0.15     0.000121
# 29  Targeting/Advertising_#5    26.932832     0.00     0.000441
# 30      Tracking_requests_#6     5.101555     0.08     0.000052
# 31                Unknown_#6     8.824939     0.01     0.000104
# 32            Performance_#6    23.503050     0.00     0.000310
# 33     Strictly_Necessary_#6    16.373086     0.00     0.000353
# 34  Targeting/Advertising_#6     0.891295     0.64     0.000016
# 35          Functionality_#6     8.862108     0.01     0.000271
# 36      Tracking_requests_#7    16.488641     0.00     0.000170
# 37  Targeting/Advertising_#7     7.125186     0.03     0.000121
# 38                Unknown_#7    27.194045     0.00     0.000321
# 39            Performance_#7    37.059105     0.00     0.000475
# 40     Strictly_Necessary_#7    13.097404     0.00     0.000277
# 41          Functionality_#7     1.564272     0.46     0.000044
# 42      Tracking_requests_#8    41.678645     0.00     0.000434
# 43            Performance_#8    59.008238     0.00     0.000835
# 44                Unknown_#8    29.406996     0.00     0.000358
# 45     Strictly_Necessary_#8    11.374067     0.00     0.000248
# 46  Targeting/Advertising_#8    10.323066     0.01     0.000206
# 47          Functionality_#8     7.579695     0.02     0.000256
# 48      Tracking_requests_#9    16.767165     0.00     0.000173
# 49                Unknown_#9    22.324331     0.00     0.000258
# 50     Strictly_Necessary_#9    21.263708     0.00     0.000430
# 51            Performance_#9    37.783110     0.00     0.000484
# 52  Targeting/Advertising_#9     4.683205     0.10     0.000075
# 53          Functionality_#9     5.312590     0.07     0.000139

# %%
# effect size (eta-squared)  results_df
import numpy as np

print("mean: " + str(np.mean(results_df["eta-squared"])))
print("std: " + str(np.std(results_df["eta-squared"])))
print("min: " + str(np.min(results_df["eta-squared"])))
print("max: " + str(np.max(results_df["eta-squared"])))
# Out:
# mean: 0.000287652471833338
# std: 0.000247746819896906
# min: 1.6382290903112786e-05
# max: 0.0013106040584470059
